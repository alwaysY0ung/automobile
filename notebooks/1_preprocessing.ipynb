# %% [markdown]
# # 불러오기, df1 만들기

# %% [markdown]
# txt파일을 열어 확인 -> 'Time','CAN', 'Identifier', 'Flage', 'DLC', 'Data', 'Counter'
# 총 7가지 features가 있다.
#
# txt형식의 데이터를 pandas.DataFrame 객체로 만들 수 있는 함수를 만들어 보자.
# 1) 파일을 로드해 line별로 읽는다
# 2) = 문자가 연속된 line의 인덱스를 찾는다
# 3) 그 다음 다음 line부터 순회하며 데이터를 적절한 리스트에 저장

# %%
cd /home/chlee/codes/automobile
# Out:
# /home/chlee/codes/automobile

# %%
def read_txt(file_path):
    # 리스트 여러개 리턴보다 딕셔너리로 묶어서 한번에 리턴이 나아보임.
    columns = {
        'Time': [],
        'CAN': [],
        'Identifier': [],
        'Flags': [],
        'DLC': [],
        'Data': [],  # 전체 데이터 문자열
        'Counter': [],
        'Error': []  # 오류 여부를 저장하는 새 컬럼 추가
    }
    
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()
        
        # 플래그 변수들
        found_separator = False
        skip_next_line = False
        
        for i, line in enumerate(lines):
            # '=' 구분자를 찾았는지 확인 (30개 이상)
            if '=' * 60 in line:
                found_separator = True
                skip_next_line = True
                continue
            
            # 구분자 다음 줄은 건너뛰기 (Trigger 정보 등)
            if skip_next_line:
                skip_next_line = False
                continue
                
            # 구분자를 찾았고, 그 다음다음 줄부터 데이터 처리
            if found_separator and not skip_next_line:
                # 공백으로 분리하여 데이터 추출
                parts = line.strip().split()
                
                if len(parts) < 4:  # 최소한 Time, CAN, Identifier, Flags는 있어야 함
                    print(f"Line {i+1}: 데이터 부족 - {line.strip()}")
                    continue
                
                try:
                    # 기본 컬럼 추출
                    time_val = parts[0]
                    can_channel = parts[1]
                    identifier = parts[2]
                    flags = parts[3]
                    
                    # ErrorFrame 특별 처리
                    if "ErrorFrame" in identifier:
                        # ErrorFrame이면 항상 "ERROR FRAME"이 있고, 마지막 필드가 Counter
                        # DLC 필드는 사용하지 않음
                        dlc = -1  # ErrorFrame의 경우 특수 값으로 표시
                        data_str = "ERROR FRAME"
                        counter = parts[-1]
                        is_error = True
                    else:
                        # 일반 프레임 처리
                        dlc = int(parts[4])  # DLC를 정수로 변환
                        # DLC 값에 따라 데이터 바이트 추출
                        data_bytes = parts[5:5+dlc]
                        data_str = " ".join(data_bytes)
                        # 남은 부분은 Counter
                        counter = parts[5+dlc] if 5+dlc < len(parts) else ""
                        is_error = False
                    
                    # 딕셔너리에 저장
                    columns['Time'].append(time_val)
                    columns['CAN'].append(can_channel)
                    columns['Identifier'].append(identifier)
                    columns['Flags'].append(flags)
                    columns['DLC'].append(dlc)
                    columns['Data'].append(data_str)
                    columns['Counter'].append(counter)
                    columns['Error'].append(is_error)
                    
                except (ValueError, IndexError) as e:
                    # 파싱 오류 발생 시 처리
                    print(f"Line {i+1} 데이터 파싱 오류: {e}")
                    print(f"오류 발생 line: {line.strip()}")
                    
                    # ErrorFrame 특별 처리를 다시 시도
                    if "ErrorFrame" in line and "ERROR" in line and "FRAME" in line:
                        # ErrorFrame 형식에 맞게 처리
                        error_parts = line.strip().split()
                        columns['Time'].append(error_parts[0] if len(error_parts) > 0 else "")
                        columns['CAN'].append(error_parts[1] if len(error_parts) > 1 else "")
                        columns['Identifier'].append("ErrorFrame")
                        columns['Flags'].append(error_parts[3] if len(error_parts) > 3 else "")
                        columns['DLC'].append(-1)
                        columns['Data'].append("ERROR FRAME")
                        columns['Counter'].append(error_parts[-1] if len(error_parts) > 5 else "")
                        columns['Error'].append(True)
                    else:
                        # 일반 오류 처리
                        columns['Time'].append(parts[0] if len(parts) > 0 else "")
                        columns['CAN'].append(parts[1] if len(parts) > 1 else "")
                        columns['Identifier'].append(parts[2] if len(parts) > 2 else "")
                        columns['Flags'].append(parts[3] if len(parts) > 3 else "")
                        columns['DLC'].append(-2)  # 기타 오류를 위한 또 다른 특수값
                        columns['Data'].append("")
                        columns['Counter'].append(parts[-1] if len(parts) > 4 else "")
                        columns['Error'].append(True)
    
    return columns

# %%
if __name__ == "__main__":
    file_path1 = ('./datasets/logfile2022-11-01_11-56-50.txt')
    file_path2 = ('./datasets/logfile2022-11-01_12-21-04.txt')
    file_path3 = ('./datasets/logfile2022-11-01_13-00-02.txt')
    file_path4 = ('./datasets/logfile2022-11-01_13-25-08.txt')
    file_path5 = ('./datasets/logfile2022-11-01_14-02-06.txt')
    file_path6 = ('./datasets/logfile2022-11-01_14-24-48.txt')
    data1 = read_txt(file_path1)
    # data2 = read_txt(file_path2)
    # data3 = read_txt(file_path3)
    # data4 = read_txt(file_path4)
    # data5 = read_txt(file_path5)
    # data6 = read_txt(file_path6)
    
    # 데이터 확인
    print(f"총 {len(data1['Time'])}개의 로그 항목을 읽었습니다.")
    print(f"정상 항목: {len(data1['Time']) - sum(data1['Error'])}개")
    print(f"오류 항목: {sum(data1['Error'])}개")
    
    # ErrorFrame 예시 출력 (data1 객체)
    error_indices = [i for i, err in enumerate(data1['Error']) if err]
    if error_indices:
        print("\nErrorFrame 예시:")
        idx = error_indices[0]
        print(f"Time: {data1['Time'][idx]}")
        print(f"CAN: {data1['CAN'][idx]}")
        print(f"Identifier: {data1['Identifier'][idx]}")
        print(f"Flags: {data1['Flags'][idx]}")
        print(f"DLC: {data1['DLC'][idx]}")
        print(f"Data: {data1['Data'][idx]}")
        print(f"Counter: {data1['Counter'][idx]}")
# Out:
# 총 3123797개의 로그 항목을 읽었습니다.
# 정상 항목: 3123785개
# 오류 항목: 12개
#
# ErrorFrame 예시:
# Time: 6.862401
# CAN: 1
# Identifier: ErrorFrame
# Flags: Rx
# DLC: -1
# Data: ERROR FRAME
# Counter: 14923

# %%
type(data1)
# Out:
# dict

# %%
import pandas as pd
import numpy as np

def convert_to_dataframe(data_dict):
    """
    딕셔너리를 판다스 DataFrame으로 변환하는 함수
   
    Parameters:
    data_dict (dict): read_txt 함수로 얻은 딕셔너리
   
    Returns:
    pandas.DataFrame: 변환된 데이터프레임
    """
    # 입력 데이터 유효성 검사
    if not isinstance(data_dict, dict):
        raise TypeError(f"입력 데이터가 딕셔너리가 아닙니다. 현재 타입: {type(data_dict)}")
   
    # 빈 딕셔너리 처리
    if not data_dict:
        print("경고: 빈 딕셔너리가 입력되었습니다.")
        return pd.DataFrame()
    
    # Data 컬럼을 16진수로 변환 (존재하는 경우)
    if 'Data' in data_dict:
        # 'Data' 컬럼의 각 항목을 16진수로 변환
        try:
            new_data = []
            for data_item in data_dict['Data']:
                if pd.notna(data_item) and data_item != '':
                    # 'ERROR' 문자열 처리
                    if data_item == 'ERROR FRAME':
                        new_data.append('ERROR FRAME')
                        continue
                        
                    try:
                        # 공백으로 구분된 문자열을 숫자 리스트로 변환
                        nums = str(data_item).split()
                        
                        # 숫자들을 바이트 배열로 변환
                        byte_array = bytes([int(num) for num in nums])
                        
                        # 바이트 배열을 바이트 리터럴 형태로 저장
                        new_data.append(byte_array)
                    except ValueError:
                        print(f"경고: 숫자로 변환할 수 없는 Data 값 발견: {data_item}")
                        new_data.append(str(data_item))
                else:
                    new_data.append(b'')
            data_dict['Data'] = new_data
        except Exception as e:
            print(f"Data 컬럼 바이트 변환 중 오류 발생: {e}")
   
    # 1. 각 키의 값 길이가 동일한지 확인
    try:
        lengths = {}
        for key, value in data_dict.items():
            try:
                lengths[key] = len(value)
            except TypeError:
                print(f"경고: '{key}' 키의 값이 길이를 측정할 수 없는 타입입니다: {type(value)}")
                lengths[key] = 1  # 기본값 설정
       
        length_values = list(lengths.values())
    except Exception as e:
        print(f"길이 검사 중 오류 발생: {e}")
        return pd.DataFrame()  # 오류 발생 시 빈 DataFrame 반환
   
    if len(set(length_values)) != 1:
        # 길이가 일치하지 않는 경우
        print(f"경고: 딕셔너리의 값 길이가 일치하지 않습니다.")
        print("각 키별 길이:")
        for key, length in lengths.items():
            print(f"  - {key}: {length}")
       
        # 가장 짧은 길이로 자르기
        min_length = min(length_values)
        print(f"모든 값을 가장 짧은 길이({min_length})로 자릅니다.")
       
        # 각 값을 자르기
        for key in data_dict.keys():
            try:
                data_dict[key] = data_dict[key][:min_length]
            except TypeError:
                print(f"경고: '{key}' 키의 값은 슬라이스할 수 없습니다.")
   
    # 2. 데이터프레임으로 변환
    try:
        df = pd.DataFrame(data_dict)
    except Exception as e:
        print(f"DataFrame 생성 중 오류 발생: {e}")
        return pd.DataFrame()
   
    # 3. 데이터 타입 변환
    try:
        # Time을 float로 변환
        df['Time'] = pd.to_numeric(df['Time'], errors='coerce')
       
        # DLC를 정수로 변환 (ErrorFrame의 경우 -1로 이미 설정됨)
        df['DLC'] = pd.to_numeric(df['DLC'], errors='coerce').astype('Int64')  # nullable integer
       
        # Counter를 정수로 변환 (빈 문자열은 NaN으로)
        if 'Counter' in df.columns:
            df['Counter'] = pd.to_numeric(df['Counter'], errors='coerce').astype('Int64')
       
        # Error를 bool로 변환
        if 'Error' in df.columns:
            df['Error'] = df['Error'].astype(bool)
    except Exception as e:
        print(f"데이터 타입 변환 중 오류 발생: {e}")
   
    # 5. 결과 요약 정보 출력
    print(f"변환 완료: {len(df)}행, {len(df.columns)}열")
   
    try:
        if 'Error' in df.columns:
            error_count = df['Error'].sum()
            print(f"ErrorFrame 수: {error_count}개")
    except Exception as e:
        print(f"ErrorFrame 개수 계산 중 오류 발생: {e}")
   
    return df

# %%
# file_paths = [
#     ('./datasets/logfile2022-11-01_11-56-50.txt'),
#     ('./datasets/logfile2022-11-01_12-21-04.txt'),
#     ('./datasets/logfile2022-11-01_13-00-02.txt'),
#     ('./datasets/logfile2022-11-01_13-25-08.txt'),
#     ('./datasets/logfile2022-11-01_14-02-06.txt'),
#     ('./datasets/logfile2022-11-01_14-24-48.txt')
# ]

# 모든 파일 통합 처리
def raw_to_df(path):
    print('=' * 20, "raw data를 dataframe으로 변환 시도 중", '=' * 20)

    dict = read_txt(path)
    df = convert_to_dataframe(dict)

    return df

df1 = raw_to_df('./datasets/logfile2022-11-01_11-56-50.txt')
# df2 = raw_to_df('./datasets/logfile2022-11-01_12-21-04.txt')
# df3 = raw_to_df('./datasets/logfile2022-11-01_13-00-02.txt')
# df4 = raw_to_df('./datasets/logfile2022-11-01_13-25-08.txt')
# df5 = raw_to_df('./datasets/logfile2022-11-01_14-02-06.txt')
# df6 = raw_to_df('./datasets/logfile2022-11-01_14-24-48.txt')
# Out:
# ==================== raw data를 dataframe으로 변환 시도 중 ====================
# 변환 완료: 3123797행, 8열
# ErrorFrame 수: 12개

# %%
df1.head()
# Out:
#        Time CAN Identifier Flags  DLC                           Data  Counter  \
# 0  0.026248   1        902    Rx    8        b'n\x84e\x04m\xc4c\xc4'        1
# 1  0.026416   1        356    Rx    4            b'\x00\x08\x0c\x04'        2
# 2  0.028296   1       1427    Rx    6                b'\x00\x01!""!'        3
# 3  0.028528   1        899    Rx    8     b'\x05(\x94qq\x00\x00\xb9'        4
# 4  0.029188   1        897    Rx    8  b'\x80\x00@\x80\xffE\x85\x01'        5
#
#    Error
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %%
# df1에서 Error 컬럼의 값이 True인 행만 출력
(df1[df1["Error"]==True])

# 근데 생각해보니 python에서는 df['Error']가 이미 불리언 시리즈이므로 ==True는 생략 가능
#error_rows = df[df['Error']]
# Out:
#                 Time CAN  Identifier Flags  DLC         Data  Counter  Error
# 14922       6.862401   1  ErrorFrame    Rx   -1  ERROR FRAME    14923   True
# 2035503   932.707966   1  ErrorFrame    Rx   -1  ERROR FRAME  2035504   True
# 3123787  1431.490367   1  ErrorFrame    Rx   -1  ERROR FRAME  3123788   True
# 3123788  1431.490401   1  ErrorFrame    Rx   -1  ERROR FRAME  3123789   True
# 3123789  1431.490427   1  ErrorFrame    Rx   -1  ERROR FRAME  3123790   True
# 3123790  1431.490445   1  ErrorFrame    Rx   -1  ERROR FRAME  3123791   True
# 3123791  1431.490461   1  ErrorFrame    Rx   -1  ERROR FRAME  3123792   True
# 3123792  1431.490477   1  ErrorFrame    Rx   -1  ERROR FRAME  3123793   True
# 3123793  1431.490501   1  ErrorFrame    Rx   -1  ERROR FRAME  3123794   True
# 3123794  1431.490517   1  ErrorFrame    Rx   -1  ERROR FRAME  3123795   True
# 3123795  1431.490537   1  ErrorFrame    Rx   -1  ERROR FRAME  3123796   True
# 3123796  1431.490559   1  ErrorFrame    Rx   -1  ERROR FRAME  3123797   True

# %%
# Error가 있는 행은 drop
df1 = df1[df1["Error"] != True]
df1 = df1.drop("Error", axis=1)

# df2 = df2[df2["Error"] != True]
# df2 = df2.drop("Error", axis=1)

# df3 = df3[df3["Error"] != True]
# df3 = df3.drop("Error", axis=1)

# df4 = df4[df4["Error"] != True]
# df4 = df4.drop("Error", axis=1)

# df5 = df5[df5["Error"] != True]
# df5 = df5.drop("Error", axis=1)

# %%
df1
# Out:
#                 Time CAN Identifier Flags  DLC  \
# 0           0.026248   1        902    Rx    8
# 1           0.026416   1        356    Rx    4
# 2           0.028296   1       1427    Rx    6
# 3           0.028528   1        899    Rx    8
# 4           0.029188   1        897    Rx    8
# ...              ...  ..        ...   ...  ...
# 3123782  1431.486713   1        356    Rx    4
# 3123783  1431.487789   1        273    Rx    8
# 3123784  1431.488031   1        274    Rx    8
# 3123785  1431.488271   1        275    Rx    8
# 3123786  1431.488420   1        354    Rx    3
#
#                                         Data  Counter
# 0                    b'n\x84e\x04m\xc4c\xc4'        1
# 1                        b'\x00\x08\x0c\x04'        2
# 2                            b'\x00\x01!""!'        3
# 3                 b'\x05(\x94qq\x00\x00\xb9'        4
# 4              b'\x80\x00@\x80\xffE\x85\x01'        5
# ...                                      ...      ...
# 3123782                  b'\x00\x08\x18\x10'  3123783
# 3123783     b'\x00\xc5y\xff\x00\x00\x00\xc5'  3123784
# 3123784     b'\xfe\x91\x00\x00g\x00\x00\x00'  3123785
# 3123785  b'\x00\x9f\x10\x80\x00\x00\x00\xb4'  3123786
# 3123786                      b'\xfb\x95\x0c'  3123787
#
# [3123785 rows x 7 columns]

# %%
# 이미 로드된 모듈 다시 로드
import importlib
from data_loader import DataLoader
importlib.reload(data_loader)

# DataLoader 인스턴스 생성
loader = DataLoader()

# 데이터프레임 저장
loader.save_dataframe(df1, 'df1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       2 import importlib
#       3 from data_loader import DataLoader
# ----> 4 importlib.reload(data_loader)
#       6 # DataLoader 인스턴스 생성
#       7 loader = DataLoader()
#
# NameError: name 'data_loader' is not defined

# %% [markdown]
# # deserialize 시작

# %%
import pandas as pd
from data_loader import DataLoader

# DataLoader 인스턴스 생성
loader = DataLoader()

# 특정 캐시 파일 직접 읽기
from pathlib import Path
cache_path = Path('./cache/df1.parquet')

# 파일 존재 여부 확인
if cache_path.exists():
    # 파일이 있다면 직접 pandas로 읽기
    df1 = pd.read_parquet(cache_path)
    print(f"파일 로드 완료: {df1.shape}")
else:
    print("파일이 존재하지 않습니다.")
# Out:
# 파일 로드 완료: (3123785, 7)

# %%
Identifiers = df1["Identifier"].unique().tolist()
print(Identifiers)
# Out:
# ['902', '356', '1427', '899', '897', '593', '688', '790', '608', '128', '129', '273', '274', '275', '339', '354', '399', '512', '544', '809', '1151', '1168', '1282', '1287', '903', '1078', '1265', '1292', '1312', '1331', '1332', '1333', '1345', '1170', '1351', '1353', '1366', '1367', '1349', '1419', '1365', '1280', '1530', '1356', '1040', '1322', '1314', '1348', '1363', '1415', '1369', '1456', '1460', '1470', '1491', '127', '1472', '66', '67', '68', '1440', '1407']

# %%
import cantools

data = df1.loc[0,'Data']

db_2015_ccan = cantools.database.load_file('datasets/hyundai_2015_ccan.dbc')
decoded = pd.Series(db_2015_ccan.decode_message(902, data))

print('*** Deserialized sensor values (902) ***\n', decoded)
# Out:
# *** Deserialized sensor values (902) ***
#  WHL_SPD_FL                  35.43750
# WHL_SPD_AliveCounter_LSB     2.00000
# WHL_SPD_FR                  35.15625
# WHL_SPD_AliveCounter_MSB     0.00000
# WHL_SPD_RL                  35.40625
# WHL_SPD_Checksum_LSB         3.00000
# WHL_SPD_RR                  35.09375
# WHL_SPD_Checksum_MSB         3.00000
# dtype: float64

# %%
df1_serialized_902 = df1[df1["Identifier"]=='902']
df1_serialized_902
# Out:
#                 Time CAN Identifier Flags  DLC  \
# 0           0.026248   1        902    Rx    8
# 49          0.046237   1        902    Rx    8
# 94          0.066232   1        902    Rx    8
# 135         0.086229   1        902    Rx    8
# 175         0.106233   1        902    Rx    8
# ...              ...  ..        ...   ...  ...
# 3123607  1431.406569   1        902    Rx    8
# 3123653  1431.426564   1        902    Rx    8
# 3123693  1431.446555   1        902    Rx    8
# 3123736  1431.466541   1        902    Rx    8
# 3123781  1431.486539   1        902    Rx    8
#
#                                      Data  Counter
# 0                 b'n\x84e\x04m\xc4c\xc4'        1
# 49                   b'q\xc4^\x04hDc\xc4'       50
# 94                   b'o\x04gDi\xc4a\xc4'       95
# 135                     b'nDeDj\xc4]\xc4'      136
# 175                  b'm\x84`Dd\x84^\x84'      176
# ...                                   ...      ...
# 3123607     b'\x01@\x01\x80\x01@\x01\xc0'  3123608
# 3123653  b'\x01\x80\x01\x80\x01@\x01\xc0'  3123654
# 3123693  b'\x01\xc0\x01\x80\x01@\x01\xc0'  3123694
# 3123736  b'\x01\x00\x01\xc0\x01@\x01\xc0'  3123737
# 3123781  b'\x00@\x01\xc0\x01\x80\x01\x80'  3123782
#
# [71580 rows x 7 columns]

# %%
(db_2015_ccan.decode_message(902, data))
# Out:
# {'WHL_SPD_FL': 35.4375,
#  'WHL_SPD_AliveCounter_LSB': 2,
#  'WHL_SPD_FR': 35.15625,
#  'WHL_SPD_AliveCounter_MSB': 0,
#  'WHL_SPD_RL': 35.40625,
#  'WHL_SPD_Checksum_LSB': 3,
#  'WHL_SPD_RR': 35.09375,
#  'WHL_SPD_Checksum_MSB': 3}

# %%
type(df1_serialized_902.loc[0,"Identifier"])
df1_serialized_902 = df1[df1["Identifier"]=='902']

# %%
def parsing_identifiers(dbc_file_path):
    """
    dbc_file_path: can bus 정보가 있는 파일의 경로 ('datasets/hyundai_2015_ccan.dbc')
    
    Return

    {
        'ID': {
            'name': '메시지 이름',
            'signals': ['시그널1', '시그널2', '시그널3', ...]
        },
        ...
    }

    """
    result = {}
    
    with open(dbc_file_path, 'r') as file:
        lines = file.readlines()
        
    i = 0
    while i < len(lines):
        line = lines[i].strip()
        
        if line.startswith('BO_'):
            # BO_ 라인 파싱
            parts = line.split()
            if len(parts) >= 3:  # BO_ 1412 AAF11: 8 AAF 형식 확인
                identifier = int(parts[1])  # CAN ID (예: 1412)
                message_name = parts[2].rstrip(':')  # 메시지 이름 (예: AAF11)
                
                # 결과 딕셔너리에 메시지 ID를 키로 하고 시그널 목록을 저장할 리스트 초기화
                result[identifier] = {"name": message_name, "signals": []}
                
                # 다음 라인부터 순회하면서 SG_ 시그널 정보 수집
                j = i + 1
                while j < len(lines) and lines[j].strip().startswith('SG_'):
                    signal_line = lines[j].strip()
                    signal_parts = signal_line.split()
                    if len(signal_parts) >= 2:
                        signal_name = signal_parts[1]  # 시그널 이름
                        result[identifier]["signals"].append(signal_name)
                    j += 1
                
                # 다음 BO_ 찾기 위해 인덱스 업데이트
                i = j - 1  # 다음 반복에서 i += 1이 실행되므로 j-1로 설정
        
        i += 1
        
    return result

# 사용 예
parsed_ID = (parsing_identifiers('datasets/hyundai_2015_ccan.dbc'))
print(parsed_ID)
# Out:
# {1532: {'name': 'ODS13', 'signals': ['CR_Ods_ID', 'CR_Ods_Chksum_H', 'CR_Ods_Chksum_L', 'CR_Ods_RomID_H', 'CR_Ods_RomID_L']}, 1531: {'name': 'ODS12', 'signals': ['CR_Ods_SerNum0', 'CR_Ods_SerNum1', 'CR_Ods_SerNum2', 'CR_Ods_SerNum3', 'CR_Ods_SerNum4', 'CR_Ods_SerNum5', 'CR_Ods_SerNum6', 'CR_Ods_SerNum7']}, 1530: {'name': 'ODS11', 'signals': ['CF_Ods_PrcCmd', 'CF_Ods_BtsFail', 'CF_Ods_AcuRcvSN', 'CF_Ods_EolCal', 'CF_Ods_PsFail', 'CF_Ods_EcuFail', 'CF_Ods_WgtStat', 'CF_Ods_OccStat', 'CR_Wcs_ErrStat', 'CR_Wcs_ClassStat']}, 1017: {'name': 'ECS12', 'signals': ['Height_FL', 'Height_FR', 'Height_RL', 'Height_RR']}, 1268: {'name': 'SPAS12', 'signals': ['CF_Spas_HMI_Stat', 'CF_Spas_Disp', 'CF_Spas_FIL_Ind', 'CF_Spas_FIR_Ind', 'CF_Spas_FOL_Ind', 'CF_Spas_FOR_Ind', 'CF_Spas_VolDown', 'CF_Spas_RIL_Ind', 'CF_Spas_RIR_Ind', 'CF_Spas_FLS_Alarm', 'CF_Spas_ROL_Ind', 'CF_Spas_ROR_Ind', 'CF_Spas_FCS_Alarm', 'CF_Spas_FI_Ind', 'CF_Spas_RI_Ind', 'CF_Spas_FRS_Alarm', 'CF_Spas_FR_Alarm', 'CF_Spas_RR_Alarm', 'CF_Spas_BEEP_Alarm', 'CF_Spas_StatAlarm', 'CF_Spas_RLS_Alarm', 'CF_Spas_RCS_Alarm', 'CF_Spas_RRS_Alarm']}, 1265: {'name': 'CLU11', 'signals': ['CF_Clu_CruiseSwState', 'CF_Clu_CruiseSwMain', 'CF_Clu_SldMainSW', 'CF_Clu_ParityBit1', 'CF_Clu_VanzDecimal', 'CF_Clu_Vanz', 'CF_Clu_SPEED_UNIT', 'CF_Clu_DetentOut', 'CF_Clu_RheostatLevel', 'CF_Clu_CluInfo', 'CF_Clu_AmpInfo', 'CF_Clu_AliveCnt1']}, 1492: {'name': 'TMU_GW_PE_01', 'signals': ['TMU_IVRActivity', 'TMU_PhoneActivity']}, 1491: {'name': 'HU_DATC_PE_00', 'signals': ['HU_VRActivity', 'HU_PhoneActivity', 'BlowerNoiseControl']}, 1490: {'name': 'HU_DATC_E_02', 'signals': ['HU_DATC_RearOnOffSet', 'HU_DATC_ADSOnOffSet']}, 1479: {'name': 'EMS21', 'signals': ['SCR_LEVEL_WARN_LAMP', 'SCR_LEVEL_WARN', 'SCR_SYS_ERROR_WARN', 'SCR_SYSTEM_WARN_LAMP', 'SCR_INDUCEMENT_EXIT_COND', 'SCR_UREA_LEVEL', 'SCR_NO_REMAINING_RESTARTS', 'SCR_REMAINING_DISTANCE']}, 1472: {'name': 'GW_Warning_PE', 'signals': ['Audio_VolumeDown', 'Pas_Spkr_Flh_Alarm', 'Pas_Spkr_Fcnt_Alarm', 'Pas_Spkr_Frh_Alarm', 'Pas_Spkr_Rlh_Alarm', 'Pas_Spkr_Rcnt_Alarm', 'Pas_Spkr_Rrh_Alarm']}, 1984: {'name': 'CAL_SAS11', 'signals': ['CCW', 'SAS_CID']}, 1456: {'name': 'CLU12', 'signals': ['CF_Clu_Odometer']}, 688: {'name': 'SAS11', 'signals': ['SAS_Angle', 'SAS_Speed', 'SAS_Stat', 'MsgCount', 'CheckSum']}, 1441: {'name': 'ACU12', 'signals': ['CR_Acu_SN']}, 1440: {'name': 'ACU11', 'signals': ['CF_Ods_SNRcv', 'CF_Ods_IDRcv', 'CF_Ods_RZReq', 'CF_Abg_DepInhEnt', 'CF_Abg_DepEnt', 'CF_PasBkl_FltStat', 'CF_DriBkl_FltStat', 'CF_PasBkl_Stat', 'CF_DriBkl_Stat', 'CF_SWL_Ind', 'CF_Acu_FltStat', 'CF_Acu_ExtOfSab', 'CF_Acu_Dtc', 'CF_Acu_NumOfFlt']}, 1437: {'name': 'AHLS11', 'signals': ['CF_Ahls_WarnLamp', 'CF_Ahls_WarnMsg']}, 1434: {'name': 'PSB11', 'signals': ['PSB_LH_FAIL', 'PSB_LH_TGL', 'PSB_LH_ACT', 'PSB_RH_FAIL', 'PSB_RH_TGL', 'PSB_RH_ACT']}, 916: {'name': 'TCS13', 'signals': ['aBasis', 'BrakeLight', 'DCEnable', 'AliveCounterTCS', 'ACCReqLim', 'TQI_ACC', 'ACCEL_REF_ACC', 'ACCEnable', 'DriverOverride', 'StandStill', 'CheckSum_TCS3', 'ACC_EQUIP', 'PBRAKE_ACT', 'ACC_REQ', 'DriverBraking', 'CF_VSM_Coded', 'CF_VSM_Avail', 'CF_VSM_Handshake', 'CF_DriBkeStat', 'CF_VSM_ConfSwi', 'AEB_EQUIP']}, 1427: {'name': 'TPMS11', 'signals': ['TPMS_W_LAMP', 'TREAD_W_LAMP', 'POS_FL_W_LAMP', 'POS_FR_W_LAMP', 'POS_RL_W_LAMP', 'POS_RR_W_LAMP', 'STATUS_TPMS', 'UNIT', 'PRESSURE_FL', 'PRESSURE_FR', 'PRESSURE_RL', 'PRESSURE_RR']}, 915: {'name': 'TCS12', 'signals': ['SA_COUNT', 'SA_Z_COUNT', 'SA_Z_FLAG']}, 1170: {'name': 'EMS19', 'signals': ['CF_Ems_BrkReq', 'CF_Ems_DnShftReq', 'CF_Ems_RepModChk', 'CF_Ems_AAFOpenReq', 'CF_Ems_DecelReq', 'CR_Ems_BstPre', 'CR_Ems_EngOilTemp', 'DPF_LAMP_STAT', 'BAT_LAMP_STAT', 'CF_Ems_ModeledAmbTemp', 'CF_Ems_OPSFail', 'CF_Ems_AliveCounterEMS9', 'CF_Ems_ChecksumEMS9']}, 1425: {'name': 'AFLS11', 'signals': ['AFLS_STAT', 'CF_Afls_TrfChgStat', 'CF_Afls_LedHLStat']}, 912: {'name': 'SPAS11', 'signals': ['CF_Spas_Stat', 'CF_Spas_TestMode', 'CR_Spas_StrAngCmd', 'CF_Spas_Bee ...

# %%
def deserialize(identifier, df,time=False):
    """
    identifier => 정수 입력
    df => Time	CAN	Identifier	Flags	DLC	Data	Counter 컬럼들이 있는 데이터프레임
    """
    filtered_df = df[df["Identifier"]==str(identifier)]

    # Data컬럼 solution1: apply 메서드
    filtered_df = filtered_df.copy()
    filtered_df['Decoded'] = filtered_df['Data'].apply(lambda x: db_2015_ccan.decode_message(identifier, x))
    # 결과를 데이터프레임으로 변환
    # decoded_series에서 딕셔너리 목록 추출
    decoded_dicts = filtered_df['Decoded'].tolist()
    
    # 딕셔너리 목록을 데이터프레임으로 변환
    result = pd.DataFrame(decoded_dicts, index=filtered_df.index)

    # 원본 데이터프레임의 Time 컬럼 추가
    result['Time'] = filtered_df['Time']

    
    # Time 컬럼을 datetime 형식으로 변환
    result['Time'] = pd.to_timedelta(result['Time'], unit='s')  # 초 단위로 해석
    
    # Time을 인덱스로 설정
    result = result.set_index('Time')

    print(f"time duplicated 처리 전 데이터프레임의 길이: {len(result)}")

    # 파라미터로 입력한 시간을 기준으로 반올림 후 중복된 시간 인덱스 중 가장 마지막 인덱스만 살리는 작업
    if time==False:
        # time값이 입력되지 않았으므로 모든 행을 그대로 둠
        pass
    else:
        # time값이 입력되었으므로 작업을 수행함
        result.index = result.index.ceil(time)
        # print(result.to_string())
        result = result[~result.index.duplicated(keep='last')]
        # print(f"time duplicated 처리 후 데이터프레임의 길이: {len(result)}")
    
    # TODO min ~ Max 사이 t 간격으로 모든 index

    if time:
        index_new = pd.timedelta_range(start=result.index.min(),
                                       end=result.index.max(), freq=time)
        result = result.reindex(index=index_new)

    # 바꿀 때 arbitrationID_컬럼명 이렇게 바꿔준다 (컬럼명 중복이 가끔 있음)
    
    identifier = hex(int(identifier))[2:]  # 16진수 변환. 인덱싱은 앞 0x를 제거하기 위함
    result.columns = [f"{identifier}_{col}" for col in result.columns]

    return result

# %%
df_deserialized_902 = deserialize(902, df1,'0.25s')
# print(df_deserialized_902.to_string())
df_deserialized_902
# Out:
# time duplicated 처리 전 데이터프레임의 길이: 71580
#                         902_WHL_SPD_FL  902_WHL_SPD_AliveCounter_LSB  \
# 0 days 00:00:00.250000        35.15625                             1
# 0 days 00:00:00.500000        34.96875                             1
# 0 days 00:00:00.750000        34.90625                             2
# 0 days 00:00:01               34.43750                             2
# 0 days 00:00:01.250000        34.53125                             3
# ...                                ...                           ...
# 0 days 00:23:50.500000         0.06250                             3
# 0 days 00:23:50.750000         0.03125                             0
# 0 days 00:23:51                0.03125                             0
# 0 days 00:23:51.250000         0.03125                             1
# 0 days 00:23:51.500000         0.00000                             1
#
#                         902_WHL_SPD_FR  902_WHL_SPD_AliveCounter_MSB  \
# 0 days 00:00:00.250000        34.84375                             3
# 0 days 00:00:00.500000        34.56250                             2
# 0 days 00:00:00.750000        34.65625                             1
# 0 days 00:00:01               34.43750                             0
# 0 days 00:00:01.250000        34.37500                             3
# ...                                ...                           ...
# 0 days 00:23:50.500000         0.06250                             2
# 0 days 00:23:50.750000         0.06250                             2
# 0 days 00:23:51                0.03125                             1
# 0 days 00:23:51.250000         0.03125                             0
# 0 days 00:23:51.500000         0.03125                             3
#
#                         902_WHL_SPD_RL  902_WHL_SPD_Checksum_LSB  \
# 0 days 00:00:00.250000        35.25000                         1
# 0 days 00:00:00.500000        34.81250                         2
# 0 days 00:00:00.750000        34.00000                         0
# 0 days 00:00:01               34.31250                         2
# 0 days 00:00:01.250000        34.31250                         1
# ...                                ...                       ...
# 0 days 00:23:50.500000         0.06250                         1
# 0 days 00:23:50.750000         0.03125                         1
# 0 days 00:23:51                0.03125                         1
# 0 days 00:23:51.250000         0.03125                         1
# 0 days 00:23:51.500000         0.03125                         2
#
#                         902_WHL_SPD_RR  902_WHL_SPD_Checksum_MSB
# 0 days 00:00:00.250000        34.87500                         3
# 0 days 00:00:00.500000        34.50000                         2
# 0 days 00:00:00.750000        34.09375                         2
# 0 days 00:00:01               34.59375                         2
# 0 days 00:00:01.250000        34.18750                         2
# ...                                ...                       ...
# 0 days 00:23:50.500000         0.06250                         3
# 0 days 00:23:50.750000         0.06250                         3
# 0 days 00:23:51                0.03125                         3
# 0 days 00:23:51.250000         0.03125                         3
# 0 days 00:23:51.500000         0.03125                         2
#
# [5726 rows x 8 columns]

# %%
try:
    df_deserialized_902 = deserialize(902, df1) # 세번째 파라미터는 시간 형식으로 입력하거나, 아예 입력하지 않아야 한다.
    df_deserialized_356 = deserialize(356, df1)
    df_merged = pd.concat([df_deserialized_902, df_deserialized_356], axis=1)
    df_merged = df_merged.sort_index()
except Exception as e:
    print(f"다음 에러가 발생: {e}\n 0.25s값을 time 파라미터로 입력하여 다시 시도합니다.")
    df_deserialized_902 = deserialize(902, df1,'0.25s') # 세번째 파라미터는 시간 형식으로 입력하거나, 아예 입력하지 않아야 한다.
    df_deserialized_356 = deserialize(356, df1,'0.25s')
    df_merged = pd.concat([df_deserialized_902, df_deserialized_356], axis=1)
    df_merged = df_merged.sort_index()
df_merged
# Out:
# time duplicated 처리 전 데이터프레임의 길이: 71580
# time duplicated 처리 전 데이터프레임의 길이: 143159
#                         WHL_SPD_FL  WHL_SPD_AliveCounter_LSB  WHL_SPD_FR  \
# Time
# 0 days 00:00:00.026248    35.43750                       2.0    35.15625
# 0 days 00:00:00.026416         NaN                       NaN         NaN
# 0 days 00:00:00.036303         NaN                       NaN         NaN
# 0 days 00:00:00.046237    35.53125                       3.0    34.93750
# 0 days 00:00:00.046405         NaN                       NaN         NaN
# ...                            ...                       ...         ...
# 0 days 00:23:51.466541     0.03125                       0.0     0.03125
# 0 days 00:23:51.466710         NaN                       NaN         NaN
# 0 days 00:23:51.476603         NaN                       NaN         NaN
# 0 days 00:23:51.486539     0.00000                       1.0     0.03125
# 0 days 00:23:51.486713         NaN                       NaN         NaN
#
#                         WHL_SPD_AliveCounter_MSB  WHL_SPD_RL  \
# Time
# 0 days 00:00:00.026248                       0.0    35.40625
# 0 days 00:00:00.026416                       NaN         NaN
# 0 days 00:00:00.036303                       NaN         NaN
# 0 days 00:00:00.046237                       0.0    35.25000
# 0 days 00:00:00.046405                       NaN         NaN
# ...                                          ...         ...
# 0 days 00:23:51.466541                       3.0     0.03125
# 0 days 00:23:51.466710                       NaN         NaN
# 0 days 00:23:51.476603                       NaN         NaN
# 0 days 00:23:51.486539                       3.0     0.03125
# 0 days 00:23:51.486713                       NaN         NaN
#
#                         WHL_SPD_Checksum_LSB  WHL_SPD_RR  \
# Time
# 0 days 00:00:00.026248                   3.0    35.09375
# 0 days 00:00:00.026416                   NaN         NaN
# 0 days 00:00:00.036303                   NaN         NaN
# 0 days 00:00:00.046237                   1.0    35.09375
# 0 days 00:00:00.046405                   NaN         NaN
# ...                                      ...         ...
# 0 days 00:23:51.466541                   1.0     0.03125
# 0 days 00:23:51.466710                   NaN         NaN
# 0 days 00:23:51.476603                   NaN         NaN
# 0 days 00:23:51.486539                   2.0     0.03125
# 0 days 00:23:51.486713                   NaN         NaN
#
#                         WHL_SPD_Checksum_MSB  CR_Esc_StrTqReq  CF_Esc_Act  \
# Time
# 0 days 00:00:00.026248                   3.0              NaN         NaN
# 0 days 00:00:00.026416                   NaN              0.0         0.0
# 0 days 00:00:00.036303                   NaN              0.0         0.0
# 0 days 00:00:00.046237                   3.0              NaN         NaN
# 0 days 00:00:00.046405                   NaN              0.0         0.0
# ...                                      ...              ...         ...
# 0 days 00:23:51.466541                   3.0              NaN         NaN
# 0 days 00:23:51.466710                   NaN              0.0         0.0
# 0 days 00:23:51.476603                   NaN              0.0         0.0
# 0 days 00:23:51.486539                   2.0              NaN         NaN
# 0 days 00:23:51.486713                   NaN              0.0         0.0
#
#                         CF_Esc_CtrMode  CF_Esc_Def  CF_Esc_AliveCnt  \
# Time
# 0 days 00:00:00.026248             NaN         NaN              NaN
# 0 days 00:00:00.026416             0.0         0.0              6.0
# 0 days 00:00:00.036303             0.0         0.0              7.0
# 0 days 00:00:00.046237             NaN         NaN              NaN
# 0 days 00:00:00.046405             0.0         0.0              8.0
# ...                                ...         ...              ...
# 0 days 00:23:51.466541             NaN         NaN              NaN
# 0 days 00:23:51.466710             0.0         0.0             10.0
# 0 days 00:23:51.476603             0.0         0.0             11.0
# 0 days 00:23:51.486539             NaN         NaN              NaN
# 0 days 00:23:51.486713             0.0         0.0             12.0
#
#                         CF_Esc_Chksum
# Time
# 0 days 00:00:00.026248            NaN
# 0 days 00:00:00.026416            4.0
# 0 days 00:00:00.036303            6.0
# 0 days 00:00:00.046237            NaN
# 0 days 00:00:00.046405           24.0
# ...                               ...
# 0 days 00:23:51.466541            NaN
# 0 days 00:23:51.466710           28.0
# 0 days 00:23:51.476603           30.0
# 0 days 00:23:51.486539            NaN
# 0 days 00:23:51.486713           16.0
#
# [214739 rows x 14 columns]

# %%
A = set(df_deserialized_902.index)
B = set(df_deserialized_356.index)

A-B
# Out:
# {Timedelta('0 days 00:12:12.264735'),
#  Timedelta('0 days 00:17:20.938831'),
#  Timedelta('0 days 00:00:31.843569'),
#  Timedelta('0 days 00:01:25.979026'),
#  Timedelta('0 days 00:00:46.443227'),
#  Timedelta('0 days 00:09:36.918725'),
#  Timedelta('0 days 00:05:28.918623'),
#  Timedelta('0 days 00:01:06.440661'),
#  Timedelta('0 days 00:15:21.728828'),
#  Timedelta('0 days 00:14:09.354905'),
#  Timedelta('0 days 00:19:45.146987'),
#  Timedelta('0 days 00:06:52.314745'),
#  Timedelta('0 days 00:10:56.431078'),
#  Timedelta('0 days 00:05:46.957109'),
#  Timedelta('0 days 00:05:13.520324'),
#  Timedelta('0 days 00:02:41.852660'),
#  Timedelta('0 days 00:17:27.178544'),
#  Timedelta('0 days 00:17:17.999071'),
#  Timedelta('0 days 00:19:57.445954'),
#  Timedelta('0 days 00:22:07.777222'),
#  Timedelta('0 days 00:00:25.124145'),
#  Timedelta('0 days 00:04:32.383382'),
#  Timedelta('0 days 00:19:12.049533'),
#  Timedelta('0 days 00:01:07.900539'),
#  Timedelta('0 days 00:05:54.116507'),
#  Timedelta('0 days 00:12:42.782139'),
#  Timedelta('0 days 00:13:57.755895'),
#  Timedelta('0 days 00:06:52.834751'),
#  Timedelta('0 days 00:08:37.903219'),
#  Timedelta('0 days 00:22:16.696209'),
#  Timedelta('0 days 00:20:19.723917'),
#  Timedelta('0 days 00:02:51.091890'),
#  Timedelta('0 days 00:17:56.215876'),
#  Timedelta('0 days 00:07:54.967093'),
#  Timedelta('0 days 00:09:31.258751'),
#  Timedelta('0 days 00:14:48.411614'),
#  Timedelta('0 days 00:14:42.932364'),
#  Timedelta('0 days 00:19:54.606167'),
#  Timedelta('0 days 00:16:13.224796'),
#  Timedelta('0 days 00:07:18.290652'),
#  Timedelta('0 days 00:02:52.551768'),
#  Timedelta('0 days 00:00:09.145492'),
#  Timedelta('0 days 00:10:58.931158'),
#  Timedelta('0 days 00:11:22.969459'),
#  Timedelta('0 days 00:12:14.484517'),
#  Timedelta('0 days 00:16:40.382219'),
#  Timedelta('0 days 00:21:12.061319'),
#  Timedelta('0 days 00:13:27.378414'),
#  Timedelta('0 days 00:17:20.758856'),
#  Timedelta('0 days 00:13:57.715894'),
#  Timedelta('0 days 00:22:46.613040'),
#  Timedelta('0 days 00:19:36.507493'),
#  Timedelta('0 days 00:10:07.255183'),
#  Timedelta('0 days 00:03:47.047849'),
#  Timedelta('0 days 00:10:13.834633'),
#  Timedelta('0 days 00:03:35.168191'),
#  Timedelta('0 days 00:08:57.321398'),
#  Timedelta('0 days 00:14:30.934232'),
#  Timedelta('0 days 00:21:01.400461'),
#  Timedelta('0 days 00:05:43.977348'),
#  Timedelta('0 days 00:16:51.001356'),
#  Timedelta('0 days 00:02:51.051889'),
#  Timedelta('0 days 00:05:29.458575'),
#  Timedelta('0 days 00:14:55.291278'),
#  Timedelta('0 days 00:22:08.577470'),
#  Timedelta('0 days 00:16:42.562024'),
#  Timedelta('0 days 00:02:27.794452'),
#  Timedelta('0 days 00:09:49.677104'),
#  Timedelta('0 days 00:16:53.981492'),
#  Timedelta('0 days 00:10:31.853117'),
#  Timedelta('0 days 00:23:18.309834'),
#  Timedelta('0 days 00:23:48.486776'),
#  Timedelta('0 days 00:23:05.330540'),
#  Timedelta('0 days 00:03:20.669415'),
#  Timedelta('0 days 00:01:24.279170'),
#  Timedelta('0 days 00:00:51.761910'),
#  Timedelta('0 days 00:10:46.892086'),
#  Timedelta('0 days 00:23:11.050057'),
#  Timedelta('0 days 00:04:44.502374'),
#  Timedelta('0 days 00:18:04.735369'),
#  Timedelta('0 days 00:07:17.170640'),
#  Timedelta('0 days 00:21:19.261066'),
#  Timedelta('0 days 00:21:31.499495'),
#  Timedelta('0 days 00:19:50.007141'),
#  Timedelta('0 days 00:18:27.213253'),
#  Timedelta('0 days 00:19:15.489246'),
#  Timedelta('0 days 00:06:03.295739'),
#  Timedelta('0 days 00:12:12.864661'),
#  Timedelta('0 days 00:12:37.763240'),
#  Timedelta('0 days 00:16:40.202244'),
#  Timedelta('0 days 00:23:42.707256'),
#  Timedelta('0 days 00:08:14.986912'),
#  Timedelta('0 days 00:11:45.487505'),
#  Timedelta('0 days 00:02:53.931651'),
#  Timedelta('0 days 00:05:48.057012'),
#  Timedelta('0 days 00:06:01.075933'),
#  Timedelta('0 days 00:07:45.488018'),
#  Timedelta('0 days 00:19:31.307926'),
#  Timedelta('0 days 00:20:32.005273'),
#  Timedelta('0 days 00:07:17.130639'),
#  Timedelta('0 days 00:07:22.450127'),
#  Timedelta('0 days 00:00:09.785419'),
#  Timedelta('0 days 00:04:17.744608'),
#  Timedelta('0 days 00:05:18.240504'),
#  Timedelta('0 days 00:05:22.943236'),
#  Timedelta('0 days 00:19:03.931334'),
#  Timedelta('0 days 00:14:19.654310'),
#  Timedelta('0 days 00:07:34.669308'),
#  Timedelta('0 days 00:16:43.741954'),
#  Timedelta('0 days 00:22:16.996239'),
#  Timedelta('0 days 00:07:33.689085'),
#  Timedelta('0 days 00:01:30.678645'),
#  Timedelta('0 days 00:16:38.722362'),
#  Timedelta('0 days 00:09:33.839125'),
#  Timedelta('0 days 00:21:46.837956'),
#  Timedelta('0 days 00:15:32.927889'),
#  Timedelta('0 days 00:17:46.596667'),
#  Timedelta('0 days 00:18:21.233975'),
#  Timedelta('0 days 00:17:09.779769'),
#  Timedelta('0 days 00:01:48.697129'),
#  Timedelta('0 days 00:09:39.658807'),
#  Timedelta('0 days 00:10:00.455789'),
#  Timedelta('0 days 00:13:35.797718'),
#  Timedelta('0 days 00:04:57.321291'),
#  Timedelta('0 days 00:07:17.029511'),
#  Timedelta('0 days 00:16:32.202891'),
#  Timedelta('0 days 00:00:11.165297'),
#  Timedelta('0 days 00:05:58.096172'),
#  Timedelta('0 days 00:15:37.987458'),
#  Timedelta('0 days 00:00:23.484266'),
#  Timedelta('0 days 00:15:51.546355'),
#  Timedelta('0 days 00:23:16.269706'),
#  Timedelta('0 days 00:04:58.041218'),
#  Timedelta('0 days 00:03:27.628841'),
#  Timedelta('0 days 00:04:42.922495'),
#  Timedelta('0 days 00:06:26.353793'),
#  Timedelta('0 days 00:01:20.419509'),
#  Timedelta('0 days 00:05:53.076580'),
#  Timedelta('0 days 00:15:15.569329'),
#  Timedelta('0 days 00:17:26.878568'),
#  Timedelta('0 days 00:20:31.345483'),
#  Timedelta('0 days 00:12:21.403942'),
#  Timedelta('0 days 00:12:50.641786'),
#  Timedelta('0 days 00:00:46.423308'),
#  Timedelta('0 days 00:00:25.544096'),
#  Timedelta('0 days 00:14:07.555050'),
#  Timedelta('0 days 00:09:40.998713'),
#  Timedelta('0 days 00:15:50.046476'),
#  Timedelta('0 days 00:22:41.513545999'),
#  Timedelta('0 days 00:13:46.596806'),
#  Timedelta('0 days 00:20:28.963471'),
#  Timedelta('0 days 00:04:19.644465'),
#  Timedelta('0 days 00:00:06.005731'),
#  Timedelta('0 days 00:06:06.835425'),
#  Timedelta('0 days 00:15:15.429355'),
#  Timedelta('0 days 00:10:29.273361'),
#  Timedelta('0 days 00:16:33.522795'),
#  Timedelta('0 days 00:10:11.234848'),
#  Timedelta('0 days 00:12:50.422026'),
#  Timedelta('0 days 00:10:24.253769'),
#  Timedelta('0 days 00:09:25.179038'),
#  Timedelta('0 days 00:09:34.239130'),
#  Timedelta('0 days 00:13:41.577399'),
#  Timedelta('0 days 00:17:08.879840'),
#  Timedelta('0 days 00:15:47.206689'),
#  Timedelta('0 days 00:06:43.354497'),
#  Timedelta('0 days 00:06:08.255303999'),
#  Timedelta('0 days 00:17:56.495853'),
#  Timedelta('0 days 00:19:55.646257'),
#  Timedelta('0 days 00:14:40.172633'),
#  Timedelta('0 days 00:12:23.423771'),
#  Timedelta('0 days 00:14:59.430700'),
#  Timedelta('0 days 00:00:00.886164'),
#  Timedelta('0 days 00:01:55.816716'),
#  Timedelta('0 days 00:21:32.019421'),
#  Timedelta('0 days 00:09:09.080440'),
#  Timedelta('0 days 00:11:24.609531'),
#  Timedelta('0 days 00:13:27.658391'),
#  Timedelta('0 days 00:12:44.262043'),
#  Timedelta('0 days 00:00:15.984917'),
#  Timedelta('0 days 00:04:16.664704'),
#  Timedelta('0 days 00:04:02.145931'),
#  Timedelta('0 days 00:00:26.084048'),
#  Timedelta('0 days 00:00:37.663088'),
#  Timedelta('0 days 00:05:01.480931'),
#  Timedelta('0 days 00:05:09.300309'),
#  Timedelta('0 days 00:21:01.680438'),
#  Timedelta('0 days 00:22:11.536911'),
#  Timedelta('0 days 00:09:18.859515'),
#  Timedelta('0 days 00:02:45.592347'),
#  Timedelta('0 days 00:06:40.894392'),
#  Timedelta('0 days 00:22:00.097441'),
#  Timedelta('0 days 00:16:56.161540'),
#  Timedelta('0 days 00:04:42.702519'),
#  Timedelta('0 days 00:23:11.990014'),
#  Timedelta('0 days 00:21:05.200151'),
#  Timedelta('0 days 00:00:00.846163'),
#  Timedelta('0 days 00:09:24.018840'),
#  Timedelta('0 days 00:00:23.024343'),
#  Timedelta('0 days 00:21:00.940512'),
#  Timedelta('0 days 00:10:45.712370'),
#  Timedelta('0 days 00:19:24.448502'),
#  Timedelta('0 days 00:16:55.521476999'),
#  Timedelta('0 days 00:01:15.159939'),
#  Timedelta('0 days 00:08:10.666978'),
#  Timedelta('0 days 00:18:10.834651'),
#  Timedelta('0 days 00:23:20.669643'),
#  Timedelta('0 days 00:02:29.074440'),
#  Timedelta('0 days 00:08:38.802934'),
#  Timedelta('0 days 00:08:11.906938'),
#  Timedelta('0 days 00:15:27.408373'),
#  Timedelta('0 days 00:17:15.979240'),
#  Timedelta('0 days 00:05:51.276749'),
#  Timedelta('0 days 00:11:43.527112'),
#  Timedelta('0 days 00:12:16.804325'),
#  Timedelta('0 days 00:15:38.347435'),
#  Timedelta('0 days 00:05:02.800835'),
#  Timedelta('0 days 00:11:07.030457'),
#  Timedelta('0 days 00:14:44.851929'),
#  Timedelta('0 days 00:09:03.501001'),
#  Timedelta('0 days 00:17:03.540299'),
#  Timedelta('0 days 00:21:44.478468'),
#  Timedelta('0 days 00:00:34.683327'),
#  Timedelta('0 days 00:07:37.448990'),
#  Timedelta('0 days 00:08:51.722040'),
#  Timedelta('0 days 00:10:03.055547'),
#  Timedelta('0 days 00:12:20.304036'),
#  Timedelta('0 days 00:00:44.082910'),
#  Timedelta('0 days 00:17:20.198878'),
#  Timedelta('0 days 00:04:30.223577'),
#  Timedelta('0 days 00:18:27.353256'),
#  Timedelta('0 days 00:09:30.519039'),
#  Timedelta('0 days 00:17:54.835996'),
#  Timedelta('0 days 00:16:36.922507'),
#  Timedelta('0 days 00:14:18.654168'),
#  Timedelta('0 days 00:19:09.169774'),
#  Timedelta('0 days 00:10:47.911773'),
#  Timedelta('0 days 00:19:26.488333'),
#  Timedelta('0 days 00:23:19.549631'),
#  Timedelta('0 days 00:13:23.918702'),
#  Timedelta('0 days 00:08:18.206408'),
#  Timedelta('0 days 00:11:06.510641'),
#  Timedelta('0 days 00:17:35.297631'),
#  Timedelta('0 days 00:21:55.057446'),
#  Timedelta('0 days 00:07:14.170960'),
#  Timedelta('0 days 00:11:01.531208'),
#  Timedelta('0 days 00:07:31.409733'),
#  Timedelta('0 days 00:06:52.754778'),
#  Timedelta('0 days 00:21:06.262081999'),
#  Timedelta('0 days 00:03:21.489344'),
#  Timedelta('0 days 00:17:00.680510'),
#  Timedelta('0 days 00:15:24.428612'),
#  Timedelta('0 days 00:20:41.342117'),
#  Timedelta('0 days 00:19:19.248935'),
#  Timedelta('0 days 00:00:18.684672'),
#  Timedelta('0 days 00:02:04.935760'),
#  Timedelta('0 days 00:18:05.635084'),
#  Timedelta('0 days 00:19:09.029800'),
#  Timedelta('0 days 00:11:01.171124'),
#  Timedelta('0 days 00:09:54.797802'),
#  Timedelta('0 days 00:16:11.444673'),
#  Timedelta('0 days 00:15:53.966352'),
#  Timedelta('0 days 00:04:51.881751'),
#  Timedelta('0 days 00:18:28.693162'),
#  Timedelta('0 days 00:06:02.035836'),
#  Timedelta('0 days 00:20:37.682430'),
#  Timedelta('0 days 00:12:11.584756'),
#  Timedelta('0 days 00:09:00.661564'),
#  Timedelta('0 days 00:01:13.600062'),
#  Timedelta('0 days 00:19:52.386174'),
#  Timedelta('0 days 00:05:09.740663'),
#  Timedelta('0 days 00:10:46.271920'),
#  Timedelta('0 days 00:07:04.113467'),
#  Timedelta('0 days 00:11:35.487785'),
#  Timedelta('0 days 00:16:17.604410'),
#  Timedelta('0 days 00:15:29.208472'),
#  Timedelta('0 days 00:02:59.751170'),
#  Timedelta('0 days 00:09:56.416099'),
#  Timedelta('0 days 00:12:15.104469'),
#  Timedelta('0 days 00:21:36.779011'),
#  Timedelta('0 days 00:11:53.526271'),
#  Timedelta('0 days 00:15:46.906713'),
#  Timedelta('0 days 00:06:33.073214'),
#  Timedelta('0 days 00:19:31.507901'),
#  Timedelta('0 days 00:15:20.728924'),
#  Timedelta('0 days 00:13:53.316254'),
#  Timedelta('0 days 00:05:17.702058'),
#  Timedelta('0 days 00:11:55.606103'),
#  Timedelta('0 days 00:01:35.138259'),
#  Timedelta('0 days 00:06:51.274682'),
#  Timedelta('0 days 00:14:11.354740'),
#  Timedelta('0 days 00:14:39.612361'),
#  Timedelta('0 days 00:20:12.364518'),
#  Timedelta('0 days 00:14:17.534479'),
#  Timedelta('0 days 00:01:22.079364'),
#  Timedelta('0 days 00:07:57.926772'),
#  Timedelta('0 days 00:13:12.839642'),
#  Timedelta('0 days 00:03:39.207908'),
#  Timedelta('0 days 00:14:22.734022'),
#  Timedelta('0 days 00:17:26.458564'),
#  Timedelta('0 days 00:21:38.478787'),
#  Timedelta('0 days 00:06:12.714947'),
#  Timedelta('0 days 00:08:01.066803'),
#  Timedelta('0 days 00:13:04.060388'),
#  Timedelta('0 days 00:13:30.878128'),
#  Timedelta('0 days 00:08:59.261254'),
#  Timedelta('0 days 00:12:07.765096'),
#  Timedelta('0 days 00:04:19.884441'),
#  Timedelta('0 days 00:19:36.247545'),
#  Timedelta('0 days 00:19:55.046144'),
#  Timedelta('0 days 00:07:32.109607'),
#  Timedelta('0 days 00:01:52.416817'),
#  Timedelta('0 days 00:04:11.105187'),
#  Timedelta('0 days 00:18:50.511633'),
#  Timedelta('0 days 00:22:03.817586'),
#  Timedelta('0 days 00:00:13.345131'),
#  Timedelta('0 days 00:02:45.052422'),
#  Timedelta('0 days 00:22:32.214001'),
#  Timedelta('0 days 00:07:39.248658'),
#  Timedelta('0 days 00:09:34.019638'),
#  Timedelta('0 days 00:08:25.565703'),
#  Timedelta('0 days 00:09:24.438791'),
#  Timedelta('0 days 00:09:15.079934'),
#  Timedelta('0 days 00:11:30.928169'),
#  Timedelta('0 days 00:03:45.627944'),
#  Timedelta('0 days 00:00:20.624506'),
#  Timedelta('0 days 00:01:24.019222'),
#  Timedelta('0 days 00:03:14.029970'),
#  Timedelta('0 days 00:14:08.374979'),
#  Timedelta('0 days 00:11:06.291015'),
#  Timedelta('0 days 00:17:44.436862'),
#  Timedelta('0 days 00:09:17.999697'),
#  Timedelta('0 days 00:14:37.992505'),
#  Timedelta('0 days 00:16:05.465149'),
#  Timedelta('0 days 00:05:53.136581'),
#  Timedelta('0 days 00:19:47.106979'),
#  Timedelta('0 days 00:20:05.085119'),
#  Timedelta('0 days 00:01:19.099603'),
#  Timedelta('0 days 00:20:20.963797'),
#  Timedelta('0 days 00:07:37.269149'),
#  Timedelta('0 days 00:14:19.434363'),
#  Timedelta('0 days 00:13:11.299762'),
#  Timedelta('0 days 00:23:03.490737'),
#  Timedelta('0 days 00:06:03.995667'),
#  Timedelta('0 days 00:00:53.761745'),
#  Timedelta('0 days 00:14:17.354504'),
#  Timedelta('0 days 00:21:44.598523'),
#  Timedelta('0 days 00:06:22.754107'),
#  Timedelta('0 days 00:07:03.153535'),
#  Timedelta('0 days 00:13:50.296492'),
#  Timedelta('0 days 00:17:05.400131'),
#  Timedelta('0 days 00:20:06.544997'),
#  Timedelta('0 days 00:09:09.460740'),
#  Timedelta('0 days 00:10:04.855405'),
#  Timedelta('0 days 00:13:46.577021'),
#  Timedelta('0 days 00:14:28.794159'),
#  Timedelta('0 days 00:21:44.018329'),
#  Timedelta('0 days 00:20:44.601855'),
#  Timedelta('0 days 00:15:48.006616'),
#  Timedelta('0 days 00:12:51.401712'),
#  Timedelta('0 days 00:13:19.099111'),
#  Timedelta('0 days 00:20:02.885310'),
#  Timedelta('0 days 00:00:21.144860'),
#  Timedelta('0 days 00:15:04.730245'),
#  Timedelta('0 days 00:01:47.217250'),
#  Timedelta('0 days 00:00:24.104218'),
#  Timedelta('0 days 00:02:04.535809'),
#  Timedelta('0 days 00:02:14.935427'),
#  Timedelta('0 days 00:10:22.873889'),
#  Timedelta('0 days 00:05:05.240620'),
#  Timedelta('0 days 00:16:34.942701'),
#  Timedelta('0 days 00:18:36.312512'),
#  Timedelta('0 days 00:19:57.865718'),
#  Timedelta('0 days 00:11:46.706848'),
#  Timedelta('0 days 00:17:58.775660'),
#  Timedelta('0 days 00:02:55.091555'),
#  Timedelta('0 days 00:16:34.282721'),
#  Timedelta('0 days 00:01:16.019869'),
#  Timedelta('0 days 00:18:51.411265'),
#  Timedelta('0 days 00:19:02.991059'),
#  Timedelta('0 days 00:17:46.256695999'),
#  Timedelta('0 days 00:20:01.385431'),
#  Timedelta('0 days 00:17:37.797414'),
#  Timedelta('0 days 00:02:03.535884999'),
#  Timedelta('0 days 00:20:07.104948'),
#  Timedelta('0 days 00:13:08.959979'),
#  Timedelta('0 days 00:23:04.990592'),
#  Timedelta('0 days 00:00:29.124160'),
#  Timedelta('0 days 00:19:26.768310'),
#  Timedelta('0 days 00:16:45.741789'),
#  Timedelta('0 days 00:11:29.248315'),
#  Timedelta('0 days 00:13:42.957119'),
#  Timedelta('0 days 00:14:22.074176'),
#  Timedelta('0 days 00:03:58.686219'),
#  Timedelta('0 days 00:13:52.476647'),
#  Timedelta('0 days 00:20:15.764230'),
#  Timedelta('0 days 00:02:08.715852'),
#  Timedelta('0 days 00:11:57.505936'),
#  Timedelta('0 days 00:08:15.586841'),
#  Timedelta('0 days 00:14:54.471109'),
#  Timedelta('0 days 00:08:45.122297'),
#  Timedelta('0 days 00:06:04.515617'),
#  Timedelta('0 days 00:09:47.178051'),
#  Timedelta('0 days 00:13:29.138271'),
#  Timedelta('0 days 00:20:18.663989'),
#  Timedelta('0 days 00:12:54.301794'),
#  Timedelta('0 days 00:21:57.397283'),
#  Timedelta('0 days 00:23:19.789607'),
#  Timedelta('0 days 00:06:27.673860'),
#  Timedelta('0 days 00:09:24.958931'),
#  Timedelta('0 days 00:17:26.038426'),
#  Timedelta('0 days 00:01:34.838283'),
#  Timedelta('0 days 00:10:38.792892'),
#  Timedelta('0 days 00:03:59.266172'),
#  Timedelta('0 days 00:22:01.097479'),
#  Timedelta('0 days 00:00:31.203618'),
#  Timedelta('0 days 00:03:05.770666'),
#  Timedelta('0 days 00:00:48.123247'),
#  Timedelta('0 days 00:04:43.462445'),
#  Timedelta('0 days 00:09:50.957119'),
#  Timedelta('0 days 00:15:24.668588'),
#  Timedelta('0 days 00:05:44.237326'),
#  Timedelta('0 days 00:21:20.320998'),
#  Timedelta('0 days 00:09:36.518750999'),
#  Timedelta('0 days 00:01:10.200348'),
#  Timedelta('0 days 00:18:20.374021'),
#  Timedelta('0 days 00:05:45.597231'),
#  Timedelta('0 days 00:00:04.405875'),
#  Timedelta('0 days 00:10:14.734562'),
#  Timedelta('0 days 00:19:43.906894'),
#  Timedelta('0 days 00:21:01.700438'),
#  Timedelta('0 days 00:21:19.601044'),
#  Timedelta('0 days 00:21:50.797836'),
#  Timedelta('0 days 00:07:40.788806'),
#  Timedelta('0 days 00:11:59.525765'),
#  Timedelta('0 days 00:16:31.162986'),
#  Timedelta('0 days 00:22:27.534224'),
#  Timedelta('0 days 00:11:45.006992'),
#  Timedelta('0 days 00:21:38.898738'),
#  Timedelta('0 days 00:01:34.798282'),
#  Timedelta('0 days 00:06:30.513431'),
#  Timedelta('0 days 00:01:24.579147'),
#  Timedelta('0 days 00:05:48.396990'),
#  Timedelta('0 days 00:22:08.377039'),
#  Timedelta('0 days 00:13:16.779306'),
#  Timedelta('0 days 00:22:40.073648'),
#  Timedelta('0 days 00:23:43.767161'),
#  Timedelta('0 days 00:04:28.083744'),
#  Timedelta('0 days 00:17:20.258879'),
#  Timedelta('0 days 00:07:35.488916'),
#  Timedelta('0 days 00:22:07.537140'),
#  Timedelta('0 days 00:11:05.830501'),
#  Timedelta('0 days 00:02:46.192300'),
#  Timedelta('0 days 00:06:14.434805'),
#  Timedelta('0 days 00:03:09.250378'),
#  Timedelta('0 days 00:17:44.856813'),
#  Timedelta('0 days 00:00:51.921913'),
#  Timedelta('0 days 00:09:18.219885'),
#  Timedelta('0 days 00:16:07.225008'),
#  Timedelta('0 days 00:17:36.077559'),
#  Timedelta('0 days 00:10:18.214274'),
#  Timedelta('0 days 00:10:31.493464'),
#  Timedelta('0 days 00:05:26.658816'),
#  Timedelta('0 days 00:19:36.627495'),
#  Timedelta('0 days 00:20:58.002603'),
#  Timedelta('0 days 00:09:32.298788'),
#  Timedelta('0 days 00:13:39.037430'),
#  Timedelta('0 days 00:15:19.469021'),
#  Timedelta('0 days 00:18:53.131147'),
#  Timedelta('0 days 00:17:54.096043'),
#  Timedelta('0 days 00:21:07.681735'),
#  Timedelta('0 days 00:02:18.755520'),
#  Timedelta('0 days 00:02:58.351293'),
#  Timedelta('0 days 00:04:30.963506'),
#  Timedelta('0 days 00:16:07.844987'),
#  Timedelta('0 days 00:17:23.158988'),
#  Timedelta('0 days 00:12:20.984366'),
#  Timedelta('0 days 00:20:58.580703'),
#  Timedelta('0 days 00:08:57.221640'),
#  Timedelta('0 days 00:09:54.957187'),
#  Timedelta('0 days 00:21:07.241865'),
#  Timedelta('0 days 00:12:57.541934'),
#  Timedelta('0 days 00:08:43.202494'),
#  Timedelta('0 days 00:14:38.972407'),
#  Timedelta('0 days 00:05:16.920467'),
#  Timedelta('0 days 00:19:32.187856'),
#  Timedelta('0 days 00:12:44.781996'),
#  Timedelta('0 days 00:17:22.998667'),
#  Timedelta('0 days 00:14:36.772603'),
#  Timedelta('0 days 00:11:26.028576'),
#  Timedelta('0 days 00:00:26.604001'),
#  Timedelta('0 days 00:12:45.501923'),
#  Timedelta('0 days 00:13:35.337742'),
#  Timedelta('0 days 00:21:10.561465'),
#  Timedelta('0 days 00:23:02.250840999'),
#  Timedelta('0 days 00:11:50.646512'),
#  Timedelta('0 days 00:23:41.347351'),
#  Timedelta('0 days 00:06:20.616018'),
#  Timedelta('0 days 00:09:24.538793'),
#  Timedelta('0 days 00:01:42.477635'),
#  Timedelta('0 days 00:19:31.427928'),
#  Timedelta('0 days 00:19:44.506839999'),
#  Timedelta('0 days 00:16:36.002579'),
#  Timedelta('0 days 00:14:40.372287'),
#  Timedelta('0 days 00:01:27.998861'),
#  Timedelta('0 days 00:22:24.654382'),
#  Timedelta('0 days 00:13:13.619570'),
#  Timedelta('0 days 00:02:33.693546'),
#  Timedelta('0 days 00:11:51.866443'),
#  Timedelta('0 days 00:00:06.305708'),
#  Timedelta('0 days 00:03:30.708575'),
#  Timedelta('0 days 00:06:48.114625'),
#  Timedelta('0 days 00:13:25.918537'),
#  Timedelta('0 days 00:06:40.614391'),
#  Timedelta('0 days 00:15:32.287938'),
#  Timedelta('0 days 00:06:13.474873'),
#  Timedelta('0 days 00:17:57.555758'),
#  Timedelta('0 days 00:18:16.314198'),
#  Timedelta('0 days 00:21:25.440458'),
#  Timedelta('0 days 00:11:51.206463'),
#  Timedelta('0 days 00:10:41.112352'),
#  Timedelta('0 days 00:14:38.792432'),
#  Timedelta('0 days 00:08:20.226430'),
#  Timedelta('0 days 00:07:32.849186'),
#  Timedelta('0 days 00:07:42.028659'),
#  Timedelta('0 days 00:07:47.188575'),
#  Timedelta('0 days 00:13:43.937021'),
#  Timedelta('0 days 00:08:47.022638'),
#  Timedelta('0 days 00:15:58.325753'),
#  Timedelta('0 days 00:06:07.615382'),
#  Timedelta('0 days 00:16:32.322893'),
#  Timedelta('0 days 00:07:19.490395'),
#  Timedelta('0 days 00:15:16.309285'),
#  Timedelta('0 days 00:04:25.723938'),
#  Timedelta('0 days 00:07:08.971396'),
#  Timedelta('0 days 00:12:54.722095'),
#  Timedelta('0 days 00:09:11.620572'),
#  Timedelta('0 days 00:16:44.621860'),
#  Timedelta('0 days 00:06:48.074624'),
#  Timedelta('0 days 00:03:03.970811'),
#  Timedelta('0 days 00:21:22.858688'),
#  Timedelta('0 days 00:11:29.488291'),
#  Timedelta('0 days 00:09:03.000890'),
#  Timedelta('0 days 00:15:29.468530'),
#  Timedelta('0 days 00:20:23.823584'),
#  Timedelta('0 days 00:19:34.167684'),
#  Timedelta('0 days 00:06:05.495549'),
#  Timedelta('0 days 00:00:45.683224'),
#  Timedelta('0 days 00:12:17.484575'),
#  Timedelta('0 days 00:09:36.258855'),
#  Timedelta('0 days 00:19:44.926827'),
#  Timedelta('0 days 00:03:23.449178'),
#  Timedelta('0 days 00:07:00.533502999'),
#  Timedelta('0 days 00:13:58.915802'),
#  Timedelta('0 days 00:22:22.074650'),
#  Timedelta('0 days 00:19:21.469038'),
#  Timedelta('0 days 00:07:53.347561'),
#  Timedelta('0 days 00:08:39.463155'),
#  Timedelta('0 days 00:11:59.805742'),
#  Timedelta('0 days 00:07:37.189176'),
#  Timedelta('0 days 00:20:22.323705'),
#  Timedelta('0 days 00:11:22.229453'),
#  Timedelta('0 days 00:13:52.576649'),
#  Timedelta('0 days 00:13:14.139520'),
#  Timedelta('0 days 00:19:34.027710'),
#  Timedelta('0 days 00:02:21.154416'),
#  Timedelta('0 days 00:03:50.006967'),
#  Timedelta('0 days 00:04:09.725283'),
#  Timedelta('0 days 00:00:11.965227'),
#  Timedelta('0 days 00:08:25.445729'),
#  Timedelta('0 days 00:14:01.876099'),
#  Timedelta('0 days 00:11:46.006896'),
#  Timedelta('0 days 00:10:22.194124'),
#  Timedelta('0 days 00:03:35.608171'),
#  Timedelta('0 days 00:08:16.386768'),
#  Timedelta('0 days 00:02:15.855679'),
#  Timedelta('0 days 00:16:32.142918'),
#  Timedelta('0 days 00:01:11.060278'),
#  Timedelta('0 days 00:22:07.817117'),
#  Timedelta('0 days 00:10:25.533649999'),
#  Timedelta('0 days 00:08:17.106695'),
#  Timedelta('0 days 00:05:51.576726'),
#  Timedelta('0 days 00:03:19.749490'),
#  Timedelta('0 days 00:05:24.878963'),
#  Timedelta('0 days 00:01:23.359245'),
#  Timedelta('0 days 00:02:19.055494'),
#  Timedelta('0 days 00:00:17.564772'),
#  Timedelta('0 days 00:00:52.281866'),
#  Timedelta('0 days 00:01:42.117685'),
#  Timedelta('0 days 00:03:59.366174'),
#  Timedelta('0 days 00:06:49.254554'),
#  Timedelta('0 days 00:12:52.261776'),
#  Timedelta('0 days 00:09:32.058759'),
#  Timedelta('0 days 00:07:15.791057'),
#  Timedelta('0 days 00:13:45.056953'),
#  Timedelta('0 days 00:22:36.793911'),
#  Timedelta('0 days 00:23:03.370763'),
#  Timedelta('0 days 00:06:24.735657'),
#  Timedelta('0 days 00:19:16.789127'),
#  Timedelta('0 days 00:19:30.348024'),
#  Timedelta('0 days 00:19:48.447075'),
#  Timedelta('0 days 00:20:35.942576'),
#  Timedelta('0 days 00:06:11.035091'),
#  Timedelta('0 days 00:17:48.656503'),
#  Timedelta('0 days 00:22:00.117470'),
#  Timedelta('0 days 00:14:12.594620'),
#  Timedelta('0 days 00:23:07.830350'),
#  Timedelta('0 days 00:23:30.229229'),
#  Timedelta('0 days 00:07:23.650035'),
#  Timedelta('0 days 00:11:42.307208'),
#  Timedelta('0 days 00:13:22.738799'),
#  Timedelta('0 days 00:00:27.743906'),
#  Timedelta('0 days 00:01:17.579725'),
#  Timedelta('0 days 00:11:24.589559'),
#  Timedelta('0 days 00:13:36.477647'),
#  Timedelta('0 days 00:21:05.320153'),
#  Timedelta('0 days 00:01:13.940040'),
#  Timedelta('0 days 00:16:52.101260'),
#  Timedelta('0 days 00:19:22.368670'),
#  Timedelta('0 days 00:05:21.882233'),
#  Timedelta('0 days 00:19:28.948120'),
#  Timedelta('0 days 00:21:00.300561'),
#  Timedelta('0 days 00:20:50.081426'),
#  Timedelta('0 days 00:14:28.834107'),
#  Timedelta('0 days 00:08:40.083270'),
#  Timedelta('0 days 00:14:51.451376'),
#  Timedelta('0 days 00:16:14.564408'),
#  Timedelta('0 days 00:07:14.911157'),
#  Timedelta('0 days 00:04:08.045429'),
#  Timedelta('0 days 00:12:27.743414'),
#  Timedelta('0 days 00:09:49.697751'),
#  Timedelta('0 days 00:11:43.647114'),
#  Timedelta('0 days 00:19:32.467833'),
#  Timedelta('0 days 00:04:45.602278'),
#  Timedelta('0 days 00:22:02.537764'),
#  Timedelta('0 days 00:11:48.846657'),
#  Timedelta('0 days 00:17:27.398898'),
#  Timedelta('0 days 00:13:01.740554'),
#  Timedelta('0 days 00:02:41.272710'),
#  Timedelta('0 days 00:19:55.505909'),
#  Timedelta('0 days 00:21:43.358702'),
#  Timedelta('0 days 00:04:36.922999'),
#  Timedelta('0 days 00:07:29.908432'),
#  Timedelta('0 days 00:09:15.319589'),
#  Timedelta('0 days 00:08:50.782033'),
#  Timedelta('0 days 00:11:01.331127'),
#  Timedelta('0 days 00:08:09.566995'),
#  Timedelta('0 days 00:08:35.003298'),
#  Timedelta('0 days 00:14:19.954316'),
#  Timedelta('0 days 00:15:41.247194'),
#  Timedelta('0 days 00:06:05.955501'),
#  Timedelta('0 days 00:21:23.600976'),
#  Timedelta('0 days 00:11:09.670511'),
#  Timedelta('0 days 00:10:31.313168'),
#  Timedelta('0 days 00:18:28.193185'),
#  Timedelta('0 days 00:18:39.772225'),
#  Timedelta('0 days 00:18:41.212106'),
#  Timedelta('0 days 00:17:35.417633'),
#  Timedelta('0 days 00:20:00.485500'),
#  Timedelta('0 days 00:20:05.845369'),
#  Timedelta('0 days 00:04:04.345741'),
#  Timedelta('0 days 00:16:21.803782'),
#  Timedelta('0 days 00:21:00.120586'),
#  Timedelta('0 days 00:03:48.067943'),
#  Timedelta('0 days 00:16:05.845128'),
#  Timedelta('0 days 00:10:20.594246'),
#  Timedelta('0 days 00:14:44.171977'),
#  Timedelta('0 days 00:16:08.644914'),
#  Timedelta('0 days 00:04:07.405796'),
#  Timedelta('0 days 00:01:41.157753'),
#  Timedelta('0 days 00:02:37.573022'),
#  Timedelta('0 days 00:04:00.686054'),
#  Timedelta('0 days 00:07:54.247169'),
#  Timedelta('0 days 00:07:59.566657'),
#  Timedelta('0 days 00:13:49.316566'),
#  Timedelta('0 days 00:13:56.415990'),
#  Timedelta('0 days 00:18:04.375179'),
#  Timedelta('0 days 00:09:27.418983'),
#  Timedelta('0 days 00:14:29.594169'),
#  Timedelta('0 days 00:01:49.817035'),
#  Timedelta('0 days 00:04:04.205767'),
#  Timedelta('0 days 00:16:15.924289'),
#  Timedelta('0 days 00:11:55.766106'),
#  Timedelta('0 days 00:10:13.694903'),
#  Timedelta('0 days 00:21:09.301562'),
#  Timedelta('0 days 00:22:06.996950'),
#  Timedelta('0 days 00:09:07.581286'),
#  Timedelta('0 days 00:18:46.911626'),
#  Timedelta('0 days 00:01:07.140614'),
#  Timedelta('0 days 00:03:45.228156'),
#  Timedelta('0 days 00:10:27.633482'),
#  Timedelta('0 days 00:11:49.286821'),
#  Timedelta('0 days 00:12:42.022214'),
#  Timedelta('0 days 00:03:13.629992'),
#  Timedelta('0 days 00:10:45.012015'),
#  Timedelta('0 days 00:15:32.527914'),
#  Timedelta('0 days 00:03:32.388432'),
#  Timedelta('0 days 00:02:09.275400'),
#  Timedelta('0 days 00:15:51.206568'),
#  Timedelta('0 days 00:16:22.363733'),
#  Timedelta('0 days 00:20:16.164206'),
#  Timedelta('0 days 00:20:53.621112'),
#  Timedelta('0 days 00:21:54.797367'),
#  Timedelta('0 days 00:02:25.374378'),
#  Timedelta('0 days 00:14:44.272300'),
#  Timedelta('0 days 00:05:07.800431'),
#  Timedelta('0 days 00:04:09.985662'),
#  Timedelta('0 days 00:03:23.729155'),
#  Timedelta('0 days 00:08:25.706108'),
#  Timedelta('0 days 00:14:46.211808'),
#  Timedelta('0 days 00:19:49.327058'),
#  Timedelta('0 days 00:21:16.061281'),
#  Timedelta('0 days 00:20:27.623274'),
#  Timedelta('0 days 00:12:28.243365'),
#  Timedelta('0 days 00:02:41.052734'),
#  Timedelta('0 days 00:06:06.475451'),
#  Timedelta('0 days 00:18:18.614004'),
#  Timedelta('0 days 00:20:01.865383'),
#  Timedelta('0 days 00:20:44.941833'),
#  Timedelta('0 days 00:20:50.681352'),
#  Timedelta('0 days 00:05:56.256316'),
#  Timedelta('0 days 00:23:27.149629'),
#  Timedelta('0 days 00:08:46.502501'),
#  Timedelta('0 days 00:02:53.351701'),
#  Timedelta('0 days 00:02:22.814300'),
#  Timedelta('0 days 00:00:24.444196'),
#  Timedelta('0 days 00:03:43.327844'),
#  Timedelta('0 days 00:01:42.537636'),
#  Timedelta('0 days 00:00:30.163713'),
#  Timedelta('0 days 00:17:43.236960'),
#  Timedelta('0 days 00:01:32.318501'),
#  Timedelta('0 days 00:10:03.675502'),
#  Timedelta('0 days 00:10:59.851221'),
#  Timedelta('0 days 00:01:51.076941'),
#  Timedelta('0 days 00:14:00.315920'),
#  Timedelta('0 days 00:03:23.689154'),
#  Timedelta('0 days 00:04:13.524973'),
#  Timedelta('0 days 00:03:01.151050'),
#  Timedelta('0 days 00:20:24.783487'),
#  Timedelta('0 days 00:11:39.807428'),
#  Timedelta('0 days 00:13:02.080529'),
#  Timedelta('0 days 00:01:52.877066'),
#  Timedelta('0 days 00:10:39.892798'),
#  Timedelta('0 days 00:15:42.447102'),
#  Timedelta('0 days 00:15:53.026639'),
#  Timedelta('0 days 00:15:06.950482'),
#  Timedelta('0 days 00:13:28.118344'),
#  Timedelta('0 days 00:12:05.005312'),
#  Timedelta('0 days 00:19:25.608409'),
#  Timedelta('0 days 00:18:57.531290999'),
#  Timedelta('0 days 00:11:03.310746'),
#  Timedelta('0 days 00:06:12.034995'),
#  Timedelta('0 days 00:00:08.885761'),
#  Timedelta('0 days 00:12:38.343063'),
#  Timedelta('0 days 00:06:35.933004'),
#  Timedelta('0 days 00:15:41.707146'),
#  Timedelta('0 days 00:16:47.501619'),
#  Timedelta('0 days 00:14:53.311208'),
#  Timedelta('0 days 00:04:56.861318'),
#  Timedelta('0 days 00:16:50.301405'),
#  Timedelta('0 days 00:22:04.217645'),
#  Timedelta('0 days 00:21:33.959229'),
#  Timedelta('0 days 00:06:24.333962'),
#  Timedelta('0 days 00:08:15.707059'),
#  Timedelta('0 days 00:12:23.023796'),
#  Timedelta('0 days 00:07:12.011102'),
#  Timedelta('0 days 00:15:17.529460'),
#  Timedelta('0 days 00:04:41.982860'),
#  Timedelta('0 days 00:18:56.431288'),
#  Timedelta('0 days 00:21:00.580538'),
#  Timedelta('0 days 00:01:48.077178'),
#  Timedelta('0 days 00:02:48.792085'),
#  Timedelta('0 days 00:16:01.066435999'),
#  Timedelta('0 days 00:11:02.471032'),
#  Timedelta('0 days 00:16:14.844385'),
#  Timedelta('0 days 00:20:23.064033'),
#  Timedelta('0 days 00:21:17.261251999'),
#  Timedelta('0 days 00:05:50.316823'),
#  Timedelta('0 days 00:07:21.950503'),
#  Timedelta('0 days 00:12:37.243023'),
#  Timedelta('0 days 00:12:43.982045'),
#  Timedelta('0 days 00:00:04.745853'),
#  Timedelta('0 days 00:04:03.105861'),
#  Timedelta('0 days 00:14:19.274067'),
#  Timedelta('0 days 00:00:33.623428'),
#  Timedelta('0 days 00:07:03.793543'),
#  Timedelta('0 days 00:17:57.435784'),
#  Timedelta('0 days 00:07:37.408749'),
#  Timedelta('0 days 00:16:51.641311'),
#  Timedelta('0 days 00:20:26.163715'),
#  Timedelta('0 days 00:22:33.214037'),
#  Timedelta('0 days 00:00:28.603836'),
#  Timedelta('0 days 00:07:18.710847'),
#  Timedelta('0 days 00:12:47.501758'),
#  Timedelta('0 days 00:02:21.214417'),
#  Timedelta('0 days 00:06:14.914757'),
#  Timedelta('0 days 00:08:18.666575'),
#  Timedelta('0 days 00:04:32.083409'),
#  Timedelta('0 days 00:12:50.301544'),
#  Timedelta('0 days 00:01:26.359006'),
#  Timedelta('0 days 00:08:46.802531'),
#  Timedelta('0 days 00:12:59.800725'),
#  Timedelta('0 days 00:06:27.535340999'),
#  Timedelta('0 days 00:23:27.749555'),
#  Timedelta('0 days 00:15:34.427747'),
#  Timedelta('0 days 00:08:04.687056'),
#  Timedelta('0 days 00:08:23.285924'),
#  Timedelta('0 days 00:00:15.544941'),
#  Timedelta('0 days 00:08:26.205655'),
#  Timedelta('0 days 00:20:13.804400'),
#  Timedelta('0 days 00:21:33.779254'),
#  Timedelta('0 days 00:02:21.074443'),
#  Timedelta('0 days 00:18:41.492083'),
#  Timedelta('0 days 00:20:00.765477'),
#  Timedelta('0 days 00:12:13.464617'),
#  Timedelta('0 days 00:11:29.368317'),
#  Timedelta('0 days 00:02:32.013505'),
#  Timedelta('0 days 00:13:59.555941'),
#  Timedelta('0 days 00:16:31.462963'),
#  Timedelta('0 days 00:08:26.725661'),
#  Timedelta('0 days 00:17:27.718660'),
#  Timedelta('0 days 00:19:52.826154'),
#  Timedelta('0 days 00:00:12.605181'),
#  Timedelta('0 days 00:07:52.707583'),
#  Timedelta('0 days 00:00:44.342915'),
#  Timedelta('0 days 00:05:52.336652'),
#  Timedelta('0 days 00:22:11.776513'),
#  Timedelta('0 days 00:00:24.904148'),
#  Timedelta('0 days 00:04:06.705550'),
#  Timedelta('0 days 00:08:06.286859'),
#  Timedelta('0 days 00:17:48.716504'),
#  Timedelta('0 days 00:18:38.552323'),
#  Timedelta('0 days 00:20:27.223323'),
#  Timedelta('0 days 00:05:29.158602'),
#  Timedelta('0 days 00:07:24.990155'),
#  Timedelta('0 days 00:00:28.344075'),
#  Timedelta('0 days 00:04:42.122569'),
#  Timedelta('0 days 00:10:31.553144'),
#  Timedelta('0 days 00:14:30.673105'),
#  Timedelta('0 days 00:11:13.930608'),
#  Timedelta('0 days 00:22:16.876241'),
#  Timedelta('0 days 00:19:39.767232'),
#  Timedelta('0 days 00:08:49.202232'),
#  Timedelta('0 days 00:04:58.721174'),
#  Timedelta('0 days 00:23:13.149841'),
#  Timedelta('0 days 00:03:15.349850'),
#  Timedelta('0 days 00:00:12.565180'),
#  Timedelta('0 days 00:21:06.080079'),
#  Timedelta('0 days 00:08:30.925891'),
#  Timedelta('0 days 00:01:41.397729'),
#  Timedelta('0 days 00:17:28.378584'),
#  Timedelta('0 days 00:07:46.348623'),
#  Timedelta('0 days 00:20:12.904471'),
#  Timedelta('0 days 00:19:15.949226'),
#  Timedelta('0 days 00:16:37.862438'),
#  Timedelta('0 days 00:20:57.420802'),
#  Timedelta('0 days 00:18:34.852635'),
#  Timedelta('0 days 00:04:46.462184'),
#  Timedelta('0 days 00:05:08.940659'),
#  Timedelta('0 days 00:04:24.684033'),
#  Timedelta('0 days 00:13:39.777627'),
#  Timedelta('0 days 00:19:51.926225'),
#  Timedelta('0 days 00:10:18.374277'),
#  Timedelta('0 days 00:07:08.151791'),
#  Timedelta('0 days 00:02:03.795859'),
#  Timedelta('0 days 00:11:36.467717'),
#  Timedelta('0 days 00:02:43.412543'),
#  Timedelta('0 days 00:19:11.649561'),
#  Timedelta('0 days 00:07:01.813983'),
#  Timedelta('0 days 00:01:37.618070'),
#  Timedelta('0 days 00:23:44.487115'),
#  Timedelta('0 days 00:10:52.351415'),
#  Timedelta('0 days 00:14:24.614041'),
#  Timedelta('0 days 00:23:06.870477'),
#  Timedelta('0 days 00:23:21.289652'),
#  Timedelta('0 days 00:09:49.037584'),
#  Timedelta('0 days 00:10:45.692211'),
#  Timedelta('0 days 00:16:59.400635'),
#  Timedelta('0 days 00:21:22.680754'),
#  Timedelta('0 days 00:07:12.911274'),
#  Timedelta('0 days 00:13:13.959548'),
#  Timedelta('0 days 00:15:26.908399'),
#  Timedelta('0 days 00:00:40.542853'),
#  Timedelta('0 days 00:11:55.206128'),
#  Timedelta('0 days 00:12:06.785168'),
#  Timedelta('0 days 00:10:45.112017'),
#  Timedelta('0 days 00:16:07.345010'),
#  Timedelta('0 days 00:11:01.251154'),
#  Timedelta('0 days 00:13:02.500496999'),
#  Timedelta('0 days 00:21:19.441098'),
#  Timedelta('0 days 00:08:46.742477'),
#  Timedelta('0 days 00:06:49.814508'),
#  Timedelta('0 days 00:09:10.900191'),
#  Timedelta('0 days 00:10:11.874803'),
#  Timedelta('0 days 00:12:08.865000'),
#  Timedelta('0 days 00:08:47.142506'),
#  Timedelta('0 days 00:08:53.801742'),
#  Timedelta('0 days 00:08:00.826991'),
#  Timedelta('0 days 00:15:55.706373'),
#  Timedelta('0 days 00:14:13.034597'),
#  Timedelta('0 days 00:03:36.008147'),
#  Timedelta('0 days 00:13:55.096084'),
#  Timedelta('0 days 00:14:55.810991'),
#  Timedelta('0 days 00:13:28.398321'),
#  Timedelta('0 days 00:10:20.214377'),
#  Timedelta('0 days 00:08:48.702364'),
#  Timedelta('0 days 00:15:53.466188'),
#  Timedelta('0 days 00:18:17.354101'),
#  Timedelta('0 days 00:18:44.051864'),
#  Timedelta('0 days 00:23:32.269223'),
#  Timedelta('0 days 00:19:56.566111'),
#  Timedelta('0 days 00:08:16.906721'),
#  Timedelta('0 days 00:07:27.209696'),
#  Timedelta('0 days 00:06:35.574693'),
#  Timedelta('0 days 00:10:04.635405'),
#  Timedelta('0 days 00:16:10.124767'),
#  Timedelta('0 days 00:01:46.297325'),
#  Timedelta('0 days 00:18:46.971627'),
#  Timedelta('0 days 00:01:30.338671'),
#  Timedelta('0 days 00:06:18.874420'),
#  Timedelta('0 days 00:15:12.349625'),
#  Timedelta('0 days 00:12:51.181712'),
#  Timedelta('0 days 00:16:38.382388'),
#  Timedelta('0 days 00:17:15.079341'),
#  Timedelta('0 days 00:23:41.507354'),
#  Timedelta('0 days 00:14:59.310702'),
#  Timedelta('0 days 00:18:47.691554'),
#  Timedelta('0 days 00:00:02.206047'),
#  Timedelta('0 days 00:01:03.540928'),
#  Timedelta('0 days 00:17:10.059749'),
#  Timedelta('0 days 00:11:51.506440'),
#  Timedelta('0 days 00:15:44.886882'),
#  Timedelta('0 days 00:08:26.145951'),
#  Timedelta('0 days 00:00:43.703231'),
#  Timedelta('0 days 00:00:25.244123'),
#  Timedelta('0 days 00:13:00.100699'),
#  Timedelta('0 days 00:20:06.185023'),
#  Timedelta('0 days 00:06:59.834043'),
#  Timedelta('0 days 00:20:37.062479'),
#  Timedelta('0 days 00:16:48.461549'),
#  Timedelta('0 days 00:00:59.161477'),
#  Timedelta('0 days 00:03:29.508673'),
#  Timedelta('0 days 00:00:07.765832'),
#  Timedelta('0 days 00:23:23.109723'),
#  Timedelta('0 days 00:02:12.015215'),
#  Timedelta('0 days 00:02:09.195427'),
#  Timedelta('0 days 00:03:57.766294'),
#  Timedelta('0 days 00:06:02.895767'),
#  Timedelta('0 days 00:08:14.466963'),
#  Timedelta('0 days 00:10:38.472569'),
#  Timedelta('0 days 00:10:58.531130'),
#  Timedelta('0 days 00:12:01.585601'),
#  Timedelta('0 days 00:14:37.592530'),
#  Timedelta('0 days 00:14:54.911089'),
#  Timedelta('0 days 00:07:54.127195'),
#  Timedelta('0 days 00:06:27.695312'),
#  Timedelta('0 days 00:14:38.952435'),
#  Timedelta('0 days 00:15:43.387003'),
#  Timedelta('0 days 00:08:53.541981'),
#  Timedelta('0 days 00:16:06.445081'),
#  Timedelta('0 days 00:18:41.912034'),
#  Timedelta('0 days 00:08:57.961032'),
#  Timedelta('0 days 00:00:19.484605'),
#  Timedelta('0 days 00:11:13.829614'),
#  Timedelta('0 days 00:19:03.271061'),
#  Timedelta('0 days 00:06:33.734727'),
#  Timedelta('0 days 00:23:24.349656'),
#  Timedelta('0 days 00:06:39.672691'),
#  Timedelta('0 days 00:04:07.005524'),
#  Timedelta('0 days 00:10:18.894417'),
#  Timedelta('0 days 00:07:58.747108'),
#  Timedelta('0 days 00:09:34.039130'),
#  Timedelta('0 days 00:08:46.422528'),
#  Timedelta('0 days 00:00:23.004318'),
#  Timedelta('0 days 00:05:28.858626'),
#  Timedelta('0 days 00:12:16.684327'),
#  Timedelta('0 days 00:06:16.534800'),
#  Timedelta('0 days 00:19:08.469823'),
#  Timedelta('0 days 00:15:13.449769'),
#  Timedelta('0 days 00:21:37.919026'),
#  Timedelta('0 days 00:20:19.803894'),
#  Timedelta('0 days 00:10:05.155355'),
#  Timedelta('0 days 00:14:18.674144'),
#  Timedelta('0 days 00:02:02.695953'),
#  Timedelta('0 days 00:15:33.967798'),
#  Timedelta('0 days 00:06:43.594717'),
#  Timedelta('0 days 00:06:47.694624'),
#  Timedelta('0 days 00:09:45.037949'),
#  Timedelta('0 days 00:06:19.096167'),
#  Timedelta('0 days 00:15:48.226620'),
#  Timedelta('0 days 00:12:12.164737'),
#  Timedelta('0 days 00:22:11.396510'),
#  Timedelta('0 days 00:03:56.926930'),
#  Timedelta('0 days 00:01:55.456555'),
#  Timedelta('0 days 00:04:14.144925'),
#  Timedelta('0 days 00:02:01.196074'),
#  Timedelta('0 days 00:10:36.852713'),
#  Timedelta('0 days 00:17:23.638619'),
#  Timedelta('0 days 00:17:56.155879'),
#  Timedelta('0 days 00:18:14.774559'),
#  ...}

# %% [markdown]
# # Merge

# %%
print(parsed_ID)
# Out:
# {1532: {'name': 'ODS13', 'signals': ['CR_Ods_ID', 'CR_Ods_Chksum_H', 'CR_Ods_Chksum_L', 'CR_Ods_RomID_H', 'CR_Ods_RomID_L']}, 1531: {'name': 'ODS12', 'signals': ['CR_Ods_SerNum0', 'CR_Ods_SerNum1', 'CR_Ods_SerNum2', 'CR_Ods_SerNum3', 'CR_Ods_SerNum4', 'CR_Ods_SerNum5', 'CR_Ods_SerNum6', 'CR_Ods_SerNum7']}, 1530: {'name': 'ODS11', 'signals': ['CF_Ods_PrcCmd', 'CF_Ods_BtsFail', 'CF_Ods_AcuRcvSN', 'CF_Ods_EolCal', 'CF_Ods_PsFail', 'CF_Ods_EcuFail', 'CF_Ods_WgtStat', 'CF_Ods_OccStat', 'CR_Wcs_ErrStat', 'CR_Wcs_ClassStat']}, 1017: {'name': 'ECS12', 'signals': ['Height_FL', 'Height_FR', 'Height_RL', 'Height_RR']}, 1268: {'name': 'SPAS12', 'signals': ['CF_Spas_HMI_Stat', 'CF_Spas_Disp', 'CF_Spas_FIL_Ind', 'CF_Spas_FIR_Ind', 'CF_Spas_FOL_Ind', 'CF_Spas_FOR_Ind', 'CF_Spas_VolDown', 'CF_Spas_RIL_Ind', 'CF_Spas_RIR_Ind', 'CF_Spas_FLS_Alarm', 'CF_Spas_ROL_Ind', 'CF_Spas_ROR_Ind', 'CF_Spas_FCS_Alarm', 'CF_Spas_FI_Ind', 'CF_Spas_RI_Ind', 'CF_Spas_FRS_Alarm', 'CF_Spas_FR_Alarm', 'CF_Spas_RR_Alarm', 'CF_Spas_BEEP_Alarm', 'CF_Spas_StatAlarm', 'CF_Spas_RLS_Alarm', 'CF_Spas_RCS_Alarm', 'CF_Spas_RRS_Alarm']}, 1265: {'name': 'CLU11', 'signals': ['CF_Clu_CruiseSwState', 'CF_Clu_CruiseSwMain', 'CF_Clu_SldMainSW', 'CF_Clu_ParityBit1', 'CF_Clu_VanzDecimal', 'CF_Clu_Vanz', 'CF_Clu_SPEED_UNIT', 'CF_Clu_DetentOut', 'CF_Clu_RheostatLevel', 'CF_Clu_CluInfo', 'CF_Clu_AmpInfo', 'CF_Clu_AliveCnt1']}, 1492: {'name': 'TMU_GW_PE_01', 'signals': ['TMU_IVRActivity', 'TMU_PhoneActivity']}, 1491: {'name': 'HU_DATC_PE_00', 'signals': ['HU_VRActivity', 'HU_PhoneActivity', 'BlowerNoiseControl']}, 1490: {'name': 'HU_DATC_E_02', 'signals': ['HU_DATC_RearOnOffSet', 'HU_DATC_ADSOnOffSet']}, 1479: {'name': 'EMS21', 'signals': ['SCR_LEVEL_WARN_LAMP', 'SCR_LEVEL_WARN', 'SCR_SYS_ERROR_WARN', 'SCR_SYSTEM_WARN_LAMP', 'SCR_INDUCEMENT_EXIT_COND', 'SCR_UREA_LEVEL', 'SCR_NO_REMAINING_RESTARTS', 'SCR_REMAINING_DISTANCE']}, 1472: {'name': 'GW_Warning_PE', 'signals': ['Audio_VolumeDown', 'Pas_Spkr_Flh_Alarm', 'Pas_Spkr_Fcnt_Alarm', 'Pas_Spkr_Frh_Alarm', 'Pas_Spkr_Rlh_Alarm', 'Pas_Spkr_Rcnt_Alarm', 'Pas_Spkr_Rrh_Alarm']}, 1984: {'name': 'CAL_SAS11', 'signals': ['CCW', 'SAS_CID']}, 1456: {'name': 'CLU12', 'signals': ['CF_Clu_Odometer']}, 688: {'name': 'SAS11', 'signals': ['SAS_Angle', 'SAS_Speed', 'SAS_Stat', 'MsgCount', 'CheckSum']}, 1441: {'name': 'ACU12', 'signals': ['CR_Acu_SN']}, 1440: {'name': 'ACU11', 'signals': ['CF_Ods_SNRcv', 'CF_Ods_IDRcv', 'CF_Ods_RZReq', 'CF_Abg_DepInhEnt', 'CF_Abg_DepEnt', 'CF_PasBkl_FltStat', 'CF_DriBkl_FltStat', 'CF_PasBkl_Stat', 'CF_DriBkl_Stat', 'CF_SWL_Ind', 'CF_Acu_FltStat', 'CF_Acu_ExtOfSab', 'CF_Acu_Dtc', 'CF_Acu_NumOfFlt']}, 1437: {'name': 'AHLS11', 'signals': ['CF_Ahls_WarnLamp', 'CF_Ahls_WarnMsg']}, 1434: {'name': 'PSB11', 'signals': ['PSB_LH_FAIL', 'PSB_LH_TGL', 'PSB_LH_ACT', 'PSB_RH_FAIL', 'PSB_RH_TGL', 'PSB_RH_ACT']}, 916: {'name': 'TCS13', 'signals': ['aBasis', 'BrakeLight', 'DCEnable', 'AliveCounterTCS', 'ACCReqLim', 'TQI_ACC', 'ACCEL_REF_ACC', 'ACCEnable', 'DriverOverride', 'StandStill', 'CheckSum_TCS3', 'ACC_EQUIP', 'PBRAKE_ACT', 'ACC_REQ', 'DriverBraking', 'CF_VSM_Coded', 'CF_VSM_Avail', 'CF_VSM_Handshake', 'CF_DriBkeStat', 'CF_VSM_ConfSwi', 'AEB_EQUIP']}, 1427: {'name': 'TPMS11', 'signals': ['TPMS_W_LAMP', 'TREAD_W_LAMP', 'POS_FL_W_LAMP', 'POS_FR_W_LAMP', 'POS_RL_W_LAMP', 'POS_RR_W_LAMP', 'STATUS_TPMS', 'UNIT', 'PRESSURE_FL', 'PRESSURE_FR', 'PRESSURE_RL', 'PRESSURE_RR']}, 915: {'name': 'TCS12', 'signals': ['SA_COUNT', 'SA_Z_COUNT', 'SA_Z_FLAG']}, 1170: {'name': 'EMS19', 'signals': ['CF_Ems_BrkReq', 'CF_Ems_DnShftReq', 'CF_Ems_RepModChk', 'CF_Ems_AAFOpenReq', 'CF_Ems_DecelReq', 'CR_Ems_BstPre', 'CR_Ems_EngOilTemp', 'DPF_LAMP_STAT', 'BAT_LAMP_STAT', 'CF_Ems_ModeledAmbTemp', 'CF_Ems_OPSFail', 'CF_Ems_AliveCounterEMS9', 'CF_Ems_ChecksumEMS9']}, 1425: {'name': 'AFLS11', 'signals': ['AFLS_STAT', 'CF_Afls_TrfChgStat', 'CF_Afls_LedHLStat']}, 912: {'name': 'SPAS11', 'signals': ['CF_Spas_Stat', 'CF_Spas_TestMode', 'CR_Spas_StrAngCmd', 'CF_Spas_Bee ...

# %%
print(Identifiers)
# Out:
# ['902', '356', '1427', '899', '897', '593', '688', '790', '608', '128', '129', '273', '274', '275', '339', '354', '399', '512', '544', '809', '1151', '1168', '1282', '1287', '903', '1078', '1265', '1292', '1312', '1331', '1332', '1333', '1345', '1170', '1351', '1353', '1366', '1367', '1349', '1419', '1365', '1280', '1530', '1356', '1040', '1322', '1314', '1348', '1363', '1415', '1369', '1456', '1460', '1470', '1491', '127', '1472', '66', '67', '68', '1440', '1407']

# %%
# 빈 리스트 생성
store =[]
t = '0.0025s'

# 각 그룹(unique한 Identifier)에 대해 for문 실행
for identifier in Identifiers:
    print(f"\n\n{(Identifiers.index(identifier)+1)}번 째 / 전체 {len(Identifiers)} 번")
    identifier = int(identifier)
    print(f"현재 처리 중인 Identifier: {identifier}")
    if identifier in parsed_ID:

        print(f"{identifier}가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.")
        
        # deserialize 함수 호출하여 데이터 변환
        new_df = deserialize(identifier, df1, t)
        store.append(new_df)
        
    else:
        print(f"{identifier}(이)가 list에 없거나 무언가 잘못되었습니다.")

# concat은 루프 밖에서하고, concat한 데이터프레임 출력
df_merged = pd.concat(store, axis=1, verify_integrity=False)
df_merged = df_merged[~df_merged.index.duplicated(keep='last')]
df_merged
# Out:
# 1번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 902
# 902가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 71580
#
#
# 2번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 356
# 356가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 143159
#
#
# 3번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1427
# 1427가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 7158
#
#
# 4번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 899
# 899가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 71741
#
#
# 5번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 897
# 897가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 71571
#
#
# 6번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 593
# 593가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 143140
#
#
# 7번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 688
# 688가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 143140
#
#
# 8번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 790
# 790가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 143160
#
#
# 9번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 608
# 608가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 143160
#
#
# 10번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 128
# 128가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 143160
#
#
# 11번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 129
# 129가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 143160
#
#
# 12번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 273
# 273가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 143143
#
#
# 13번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 274
# 274가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 143143
#
#
# 14번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 275
# 275가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 143143
#
#
# 15번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 339
# 339가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 143158
#
#
# 16번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 354
# 354가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 143143
#
#
# 17번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 399
# 399가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 143160
#
#
# 18번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 512
# 512가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 143160
#
#
# 19번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 544
# 544가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 143158
#
#
# 20번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 809
# 809가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 143160
#
#
# 21번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1151
# 1151가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 71579
#
#
# 22번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1168
# 1168가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 28632
#
#
# 23번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1282
# 1282가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 14315
#
#
# 24번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1287
# 1287가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 14316
#
#
# 25번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 903
# 903가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 71579
#
#
# 26번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1078
# 1078가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 28645
#
#
# 27번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1265
# 1265가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 71591
#
#
# 28번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1292
# 1292가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 14319
#
#
# 29번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1312
# 1312가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 14323
#
#
# 30번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1331
# 1331(이)가 list에 없거나 무언가 잘못되었습니다.
#
#
# 31번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1332
# 1332(이)가 list에 없거나 무언가 잘못되었습니다.
#
#
# 32번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1333
# 1333(이)가 list에 없거나 무언가 잘못되었습니다.
#
#
# 33번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1345
# 1345가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 15170
#
#
# 34번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1170
# 1170가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 28632
#
#
# 35번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1351
# 1351가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 14316
#
#
# 36번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1353
# 1353가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 14316
#
#
# 37번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1366
# 1366가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 14316
#
#
# 38번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1367
# 1367가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 14316
#
#
# 39번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1349
# 1349가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 14316
#
#
# 40번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1419
# 1419가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 14315
#
#
# 41번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1365
# 1365가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 14336
#
#
# 42번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1280
# 1280가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 14337
#
#
# 43번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1530
# 1530가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 1431
#
#
# 44번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1356
# 1356가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 7157
#
#
# 45번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1040
# 1040가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 7161
#
#
# 46번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1322
# 1322가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 13967
#
#
# 47번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1314
# 1314가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 7161
#
#
# 48번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1348
# 1348(이)가 list에 없거나 무언가 잘못되었습니다.
#
#
# 49번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1363
# 1363가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 7202
#
#
# 50번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1415
# 1415가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 7157
#
#
# 51번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1369
# 1369가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 7161
#
#
# 52번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1456
# 1456가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 1432
#
#
# 53번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1460
# 1460(이)가 list에 없거나 무언가 잘못되었습니다.
#
#
# 54번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1470
# 1470(이)가 list에 없거나 무언가 잘못되었습니다.
#
#
# 55번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1491
# 1491가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 1432
#
#
# 56번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 127
# 127가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 1432
#
#
# 57번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1472
# 1472가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 1432
#
#
# 58번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 66
# 66가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 1435
#
#
# 59번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 67
# 67가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 1435
#
#
# 60번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 68
# 68가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 1495
#
#
# 61번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1440
# 1440가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 1433
#
#
# 62번 째 / 전체 62 번
# 현재 처리 중인 Identifier: 1407
# 1407가 CAN.dbc 파일에 존재합니다. 인덱스는 Time이며, Deserialize 작업을 시작합니다.
# time duplicated 처리 전 데이터프레임의 길이: 716
#                         386_WHL_SPD_FL  386_WHL_SPD_AliveCounter_LSB  \
# 0 days 00:00:00.027500         35.4375                           2.0
# 0 days 00:00:00.030000             NaN                           NaN
# 0 days 00:00:00.032500             NaN                           NaN
# 0 days 00:00:00.035000             NaN                           NaN
# 0 days 00:00:00.037500             NaN                           NaN
# ...                                ...                           ...
# 0 days 00:23:51.480000             NaN                           NaN
# 0 days 00:23:51.482500             NaN                           NaN
# 0 days 00:23:51.485000             NaN                           NaN
# 0 days 00:23:51.487500          0.0000                           1.0
# 0 days 00:23:51.490000             NaN                           NaN
#
#                         386_WHL_SPD_FR  386_WHL_SPD_AliveCounter_MSB  \
# 0 days 00:00:00.027500        35.15625                           0.0
# 0 days 00:00:00.030000             NaN                           NaN
# 0 days 00:00:00.032500             NaN                           NaN
# 0 days 00:00:00.035000             NaN                           NaN
# 0 days 00:00:00.037500             NaN                           NaN
# ...                                ...                           ...
# 0 days 00:23:51.480000             NaN                           NaN
# 0 days 00:23:51.482500             NaN                           NaN
# 0 days 00:23:51.485000             NaN                           NaN
# 0 days 00:23:51.487500         0.03125                           3.0
# 0 days 00:23:51.490000             NaN                           NaN
#
#                         386_WHL_SPD_RL  386_WHL_SPD_Checksum_LSB  \
# 0 days 00:00:00.027500        35.40625                       3.0
# 0 days 00:00:00.030000             NaN                       NaN
# 0 days 00:00:00.032500             NaN                       NaN
# 0 days 00:00:00.035000             NaN                       NaN
# 0 days 00:00:00.037500             NaN                       NaN
# ...                                ...                       ...
# 0 days 00:23:51.480000             NaN                       NaN
# 0 days 00:23:51.482500             NaN                       NaN
# 0 days 00:23:51.485000             NaN                       NaN
# 0 days 00:23:51.487500         0.03125                       2.0
# 0 days 00:23:51.490000             NaN                       NaN
#
#                         386_WHL_SPD_RR  386_WHL_SPD_Checksum_MSB  \
# 0 days 00:00:00.027500        35.09375                       3.0
# 0 days 00:00:00.030000             NaN                       NaN
# 0 days 00:00:00.032500             NaN                       NaN
# 0 days 00:00:00.035000             NaN                       NaN
# 0 days 00:00:00.037500             NaN                       NaN
# ...                                ...                       ...
# 0 days 00:23:51.480000             NaN                       NaN
# 0 days 00:23:51.482500             NaN                       NaN
# 0 days 00:23:51.485000             NaN                       NaN
# 0 days 00:23:51.487500         0.03125                       2.0
# 0 days 00:23:51.490000             NaN                       NaN
#
#                         164_CR_Esc_StrTqReq  164_CF_Esc_Act  ...  \
# 0 days 00:00:00.027500                  0.0             0.0  ...
# 0 days 00:00:00.030000                  NaN             NaN  ...
# 0 days 00:00:00.032500                  NaN             NaN  ...
# 0 days 00:00:00.035000                  NaN             NaN  ...
# 0 days 00:00:00.037500                  0.0             0.0  ...
# ...                                     ...             ...  ...
# 0 days 00:23:51.480000                  NaN             NaN  ...
# 0 days 00:23:51.482500                  NaN             NaN  ...
# 0 days 00:23:51.485000                  NaN             NaN  ...
# 0 days 00:23:51.487500                  0.0             0.0  ...
# 0 days 00:23:51.490000                  NaN             NaN  ...
#
#                         5a0_CF_PasBkl_FltStat  5a0_CF_DriBkl_FltStat  \
# 0 days 00:00:00.027500                    NaN                    NaN
# 0 days 00:00:00.030000                    NaN                    NaN
# 0 days 00:00:00.032500                    NaN                    NaN
# 0 days 00:00:00.035000                    NaN                    NaN
# 0 days 00:00:00.037500                    NaN                    NaN
# ...                                       ...                    ...
# 0 days 00:23:51.480000                    NaN                    NaN
# 0 days 00:23:51.482500                    NaN                    NaN
# 0 days 00:23:51.485000                    NaN                    NaN
# 0 days 00:23:51.487500                    NaN                    NaN
# 0 days 00:23:51.490000                    NaN                    NaN
#
#                         5a0_CF_PasBkl_Stat  5a0_CF_DriBkl_Stat  \
# 0 days 00:00:00.027500                 NaN                 NaN
# 0 days 00:00:00.030000                 NaN                 NaN
# 0 days 00:00:00.032500                 NaN                 NaN
# 0 days 00:00:00.035000                 NaN                 NaN
# 0 days 00:00:00.037500                 NaN                 NaN
# ...                                    ...                 ...
# 0 days 00:23:51.480000                 NaN                 NaN
# 0 days 00:23:51.482500                 NaN                 NaN
# 0 days 00:23:51.485000                 NaN                 NaN
# 0 days 00:23:51.487500                 NaN                 NaN
# 0 days 00:23:51.490000                 NaN                 NaN
#
#                         5a0_CF_SWL_Ind  5a0_CF_Acu_FltStat  \
# 0 days 00:00:00.027500             NaN                 NaN
# 0 days 00:00:00.030000             NaN                 NaN
# 0 days 00:00:00.032500             NaN                 NaN
# 0 days 00:00:00.035000             NaN                 NaN
# 0 days 00:00:00.037500             NaN                 NaN
# ...                                ...                 ...
# 0 days 00:23:51.480000             NaN                 NaN
# 0 days 00:23:51.482500             NaN                 NaN
# 0 days 00:23:51.485000             NaN                 NaN
# 0 days 00:23:51.487500             NaN                 NaN
# 0 days 00:23:51.490000             NaN                 NaN
#
#                         5a0_CF_Acu_ExtOfSab  5a0_CF_Acu_Dtc  \
# 0 days 00:00:00.027500                  NaN             NaN
# 0 days 00:00:00.030000                  NaN             NaN
# 0 days 00:00:00.032500                  NaN             NaN
# 0 days 00:00:00.035000                  NaN             NaN
# 0 days 00:00:00.037500                  NaN             NaN
# ...                                     ...             ...
# 0 days 00:23:51.480000                  NaN             NaN
# 0 days 00:23:51.482500                  NaN             NaN
# 0 days 00:23:51.485000                  NaN             NaN
# 0 days 00:23:51.487500                  NaN             NaN
# 0 days 00:23:51.490000                  NaN             NaN
#
#                         5a0_CF_Acu_NumOfFlt  57f_HU_Type
# 0 days 00:00:00.027500                  NaN          NaN
# 0 days 00:00:00.030000                  NaN          NaN
# 0 days 00:00:00.032500                  NaN          NaN
# 0 days 00:00:00.035000                  NaN          NaN
# 0 days 00:00:00.037500                  NaN          NaN
# ...                                     ...          ...
# 0 days 00:23:51.480000                  NaN          NaN
# 0 days 00:23:51.482500                  NaN          NaN
# 0 days 00:23:51.485000                  NaN          NaN
# 0 days 00:23:51.487500                  NaN          NaN
# 0 days 00:23:51.490000                  NaN          NaN
#
# [572586 rows x 688 columns]

# %%
importlib.reload(data_loader)
name = 'df_merged' + '_' + t[2:]
loader.save_dataframe(df_merged, name, write=True)
# Out:
# df_merged_0025s.parquet 파일이 이미 존재하지만 덮어씌웁니다.
# True

# %%
# 시간간격 조절하여 데이터 로드 가능
t = '0.0025s'

name = './cache/df_merged_' + t[2:] + '.parquet'
df_merged = pd.read_parquet(name)
df_merged
# Out:
#                         386_WHL_SPD_FL  386_WHL_SPD_AliveCounter_LSB  \
# 0 days 00:00:00.027500         35.4375                           2.0
# 0 days 00:00:00.030000             NaN                           NaN
# 0 days 00:00:00.032500             NaN                           NaN
# 0 days 00:00:00.035000             NaN                           NaN
# 0 days 00:00:00.037500             NaN                           NaN
# ...                                ...                           ...
# 0 days 00:23:51.480000             NaN                           NaN
# 0 days 00:23:51.482500             NaN                           NaN
# 0 days 00:23:51.485000             NaN                           NaN
# 0 days 00:23:51.487500          0.0000                           1.0
# 0 days 00:23:51.490000             NaN                           NaN
#
#                         386_WHL_SPD_FR  386_WHL_SPD_AliveCounter_MSB  \
# 0 days 00:00:00.027500        35.15625                           0.0
# 0 days 00:00:00.030000             NaN                           NaN
# 0 days 00:00:00.032500             NaN                           NaN
# 0 days 00:00:00.035000             NaN                           NaN
# 0 days 00:00:00.037500             NaN                           NaN
# ...                                ...                           ...
# 0 days 00:23:51.480000             NaN                           NaN
# 0 days 00:23:51.482500             NaN                           NaN
# 0 days 00:23:51.485000             NaN                           NaN
# 0 days 00:23:51.487500         0.03125                           3.0
# 0 days 00:23:51.490000             NaN                           NaN
#
#                         386_WHL_SPD_RL  386_WHL_SPD_Checksum_LSB  \
# 0 days 00:00:00.027500        35.40625                       3.0
# 0 days 00:00:00.030000             NaN                       NaN
# 0 days 00:00:00.032500             NaN                       NaN
# 0 days 00:00:00.035000             NaN                       NaN
# 0 days 00:00:00.037500             NaN                       NaN
# ...                                ...                       ...
# 0 days 00:23:51.480000             NaN                       NaN
# 0 days 00:23:51.482500             NaN                       NaN
# 0 days 00:23:51.485000             NaN                       NaN
# 0 days 00:23:51.487500         0.03125                       2.0
# 0 days 00:23:51.490000             NaN                       NaN
#
#                         386_WHL_SPD_RR  386_WHL_SPD_Checksum_MSB  \
# 0 days 00:00:00.027500        35.09375                       3.0
# 0 days 00:00:00.030000             NaN                       NaN
# 0 days 00:00:00.032500             NaN                       NaN
# 0 days 00:00:00.035000             NaN                       NaN
# 0 days 00:00:00.037500             NaN                       NaN
# ...                                ...                       ...
# 0 days 00:23:51.480000             NaN                       NaN
# 0 days 00:23:51.482500             NaN                       NaN
# 0 days 00:23:51.485000             NaN                       NaN
# 0 days 00:23:51.487500         0.03125                       2.0
# 0 days 00:23:51.490000             NaN                       NaN
#
#                         164_CR_Esc_StrTqReq  164_CF_Esc_Act  ...  \
# 0 days 00:00:00.027500                  0.0             0.0  ...
# 0 days 00:00:00.030000                  NaN             NaN  ...
# 0 days 00:00:00.032500                  NaN             NaN  ...
# 0 days 00:00:00.035000                  NaN             NaN  ...
# 0 days 00:00:00.037500                  0.0             0.0  ...
# ...                                     ...             ...  ...
# 0 days 00:23:51.480000                  NaN             NaN  ...
# 0 days 00:23:51.482500                  NaN             NaN  ...
# 0 days 00:23:51.485000                  NaN             NaN  ...
# 0 days 00:23:51.487500                  0.0             0.0  ...
# 0 days 00:23:51.490000                  NaN             NaN  ...
#
#                         5a0_CF_PasBkl_FltStat  5a0_CF_DriBkl_FltStat  \
# 0 days 00:00:00.027500                    NaN                    NaN
# 0 days 00:00:00.030000                    NaN                    NaN
# 0 days 00:00:00.032500                    NaN                    NaN
# 0 days 00:00:00.035000                    NaN                    NaN
# 0 days 00:00:00.037500                    NaN                    NaN
# ...                                       ...                    ...
# 0 days 00:23:51.480000                    NaN                    NaN
# 0 days 00:23:51.482500                    NaN                    NaN
# 0 days 00:23:51.485000                    NaN                    NaN
# 0 days 00:23:51.487500                    NaN                    NaN
# 0 days 00:23:51.490000                    NaN                    NaN
#
#                         5a0_CF_PasBkl_Stat  5a0_CF_DriBkl_Stat  \
# 0 days 00:00:00.027500                 NaN                 NaN
# 0 days 00:00:00.030000                 NaN                 NaN
# 0 days 00:00:00.032500                 NaN                 NaN
# 0 days 00:00:00.035000                 NaN                 NaN
# 0 days 00:00:00.037500                 NaN                 NaN
# ...                                    ...                 ...
# 0 days 00:23:51.480000                 NaN                 NaN
# 0 days 00:23:51.482500                 NaN                 NaN
# 0 days 00:23:51.485000                 NaN                 NaN
# 0 days 00:23:51.487500                 NaN                 NaN
# 0 days 00:23:51.490000                 NaN                 NaN
#
#                         5a0_CF_SWL_Ind  5a0_CF_Acu_FltStat  \
# 0 days 00:00:00.027500             NaN                 NaN
# 0 days 00:00:00.030000             NaN                 NaN
# 0 days 00:00:00.032500             NaN                 NaN
# 0 days 00:00:00.035000             NaN                 NaN
# 0 days 00:00:00.037500             NaN                 NaN
# ...                                ...                 ...
# 0 days 00:23:51.480000             NaN                 NaN
# 0 days 00:23:51.482500             NaN                 NaN
# 0 days 00:23:51.485000             NaN                 NaN
# 0 days 00:23:51.487500             NaN                 NaN
# 0 days 00:23:51.490000             NaN                 NaN
#
#                         5a0_CF_Acu_ExtOfSab  5a0_CF_Acu_Dtc  \
# 0 days 00:00:00.027500                  NaN             NaN
# 0 days 00:00:00.030000                  NaN             NaN
# 0 days 00:00:00.032500                  NaN             NaN
# 0 days 00:00:00.035000                  NaN             NaN
# 0 days 00:00:00.037500                  NaN             NaN
# ...                                     ...             ...
# 0 days 00:23:51.480000                  NaN             NaN
# 0 days 00:23:51.482500                  NaN             NaN
# 0 days 00:23:51.485000                  NaN             NaN
# 0 days 00:23:51.487500                  NaN             NaN
# 0 days 00:23:51.490000                  NaN             NaN
#
#                         5a0_CF_Acu_NumOfFlt  57f_HU_Type
# 0 days 00:00:00.027500                  NaN          NaN
# 0 days 00:00:00.030000                  NaN          NaN
# 0 days 00:00:00.032500                  NaN          NaN
# 0 days 00:00:00.035000                  NaN          NaN
# 0 days 00:00:00.037500                  NaN          NaN
# ...                                     ...          ...
# 0 days 00:23:51.480000                  NaN          NaN
# 0 days 00:23:51.482500                  NaN          NaN
# 0 days 00:23:51.485000                  NaN          NaN
# 0 days 00:23:51.487500                  NaN          NaN
# 0 days 00:23:51.490000                  NaN          NaN
#
# [572586 rows x 688 columns]

# %%
the_107_signals = [
    '044_CR_Datc_OutTempC', '044_CF_Datc_IncarTemp', '080_PV_AV_CAN', '080_N', '080_TQI_ACOR',
    '080_TQFR', '080_TQI', '081_BRAKE_ACT', '081_CF_Ems_EngOperStat', '081_CR_Ems_IndAirTemp',
    '111_TQI_TCU_INC', '111_SWI_GS', '111_TQI_TCU', '111_SWI_CC', '112_VS_TCU', '112_N_INC_TCU',
    '112_VS_TCU_DECIMAL', '113_SLOPE_TCU', '113_CF_Tcu_TarGr', '113_CF_Tcu_ShfPatt', '113_CF_Tcu_ActEcoRdy',
    '162_Clutch_Driving_Tq', '162_Cluster_Engine_RPM', '162_Cluster_Engine_RPM_Flag', '18F_R_PAcnC', '18F_TQI_B',
    '18F_R_NEngIdlTgC', '200_FCO', '220_LAT_ACCEL', '220_LONG_ACCEL', '220_CYL_PRES', '220_YAW_RATE',
    '251_CR_Mdps_StrTq', '251_CR_Mdps_OutTq', '260_TQI_MIN', '260_TQI', '260_TQI_TARGET', '260_TQI_MAX',
    '260_CF_Ems_AclAct', '2B0_SAS_Angle', '2B0_SAS_Speed', '316_PUC_STAT', '316_TQI_ACOR', '316_N', '316_TQI',
    '316_TQFR', '316_VS', '329_TEMP_ENG', '329_MAF_FAC_ALTI_MMV', '329_CLU_ACK', '329_BRAKE_ACT', '329_TPS',
    '329_PV_AV_CAN', '381_CR_Mdps_StrAng', '383_CR_Fatc_OutTemp', '383_CR_Fatc_OutTempSns', '386_WHL_SPD_FL',
    '386_WHL_SPD_FR', '386_WHL_SPD_RL', '386_WHL_SPD_RR', '387_WHL_PUL_FL', '387_WHL_PUL_FR', '387_WHL_PUL_RL',
    '387_WHL_PUL_RR', '47F_ROL_CNT_ESP', '4F1_CF_Clu_VanzDecimal', '4F1_CF_Clu_Vanz', '4F1_CF_Clu_DetentOut',
    '50C_CF_Clu_AvgFCI', '50C_CF_Clu_DTE', '52A_CF_Clu_VehicleSpeed', '541_CF_Gway_TurnSigLh',
    '541_CF_Gway_HeadLampLow', '541_CF_Gway_TurnSigRh', '545_AMP_CAN', '545_BAT_Alt_FR_Duty',
    '545_VB', '545_TEMP_FUEL', '547_ECGPOvrd', '547_IntAirTemp', '549_BAT_SNSR_I', '549_BAT_SOC',
    '549_BAT_SNSR_V', '549_BAT_SNSR_Temp', '553_CF_Gway_AutoLightValue', '553_CF_Gway_AvTail',
    '553_CF_Gway_ExtTailAct', '553_CF_Gway_IntTailAct', '555_CR_Fpcm_LPActPre', '556_PID_04h',
    '556_PID_05h', '556_PID_0Ch', '556_PID_0Dh', '556_PID_11h', '557_PID_0Bh', '557_PID_23h',
    '58B_CF_Lca_Stat', '58B_CF_Lca_IndLeft', '58B_CF_Lca_IndRight', '58B_CF_Lca_IndBriLeft',
    '58B_CF_Lca_IndBriRight', '593_PRESSURE_FL', '593_PRESSURE_FR', '593_PRESSURE_RL',
    '593_PRESSURE_RR', '5A0_CF_Acu_Dtc', '5B0_CF_Clu_Odometer'
]

for i in my:
    if i in the_107_signals:
        print(i)

# df_merged = df_merged[[col for col in the_107_signals if col in df_merged.columns]]

# %%
df_merged.head(30)
# Out:
#                         386_WHL_SPD_FL  386_WHL_SPD_AliveCounter_LSB  \
# 0 days 00:00:00.027500        35.43750                           2.0
# 0 days 00:00:00.030000             NaN                           NaN
# 0 days 00:00:00.032500             NaN                           NaN
# 0 days 00:00:00.035000             NaN                           NaN
# 0 days 00:00:00.037500             NaN                           NaN
# 0 days 00:00:00.040000             NaN                           NaN
# 0 days 00:00:00.042500             NaN                           NaN
# 0 days 00:00:00.045000             NaN                           NaN
# 0 days 00:00:00.047500        35.53125                           3.0
# 0 days 00:00:00.050000             NaN                           NaN
# 0 days 00:00:00.052500             NaN                           NaN
# 0 days 00:00:00.055000             NaN                           NaN
# 0 days 00:00:00.057500             NaN                           NaN
# 0 days 00:00:00.060000             NaN                           NaN
# 0 days 00:00:00.062500             NaN                           NaN
# 0 days 00:00:00.065000             NaN                           NaN
# 0 days 00:00:00.067500        35.46875                           0.0
# 0 days 00:00:00.070000             NaN                           NaN
# 0 days 00:00:00.072500             NaN                           NaN
# 0 days 00:00:00.075000             NaN                           NaN
# 0 days 00:00:00.077500             NaN                           NaN
# 0 days 00:00:00.080000             NaN                           NaN
# 0 days 00:00:00.082500             NaN                           NaN
# 0 days 00:00:00.085000             NaN                           NaN
# 0 days 00:00:00.087500        35.43750                           1.0
# 0 days 00:00:00.090000             NaN                           NaN
# 0 days 00:00:00.092500             NaN                           NaN
# 0 days 00:00:00.095000             NaN                           NaN
# 0 days 00:00:00.097500             NaN                           NaN
# 0 days 00:00:00.100000             NaN                           NaN
#
#                         386_WHL_SPD_FR  386_WHL_SPD_AliveCounter_MSB  \
# 0 days 00:00:00.027500        35.15625                           0.0
# 0 days 00:00:00.030000             NaN                           NaN
# 0 days 00:00:00.032500             NaN                           NaN
# 0 days 00:00:00.035000             NaN                           NaN
# 0 days 00:00:00.037500             NaN                           NaN
# 0 days 00:00:00.040000             NaN                           NaN
# 0 days 00:00:00.042500             NaN                           NaN
# 0 days 00:00:00.045000             NaN                           NaN
# 0 days 00:00:00.047500        34.93750                           0.0
# 0 days 00:00:00.050000             NaN                           NaN
# 0 days 00:00:00.052500             NaN                           NaN
# 0 days 00:00:00.055000             NaN                           NaN
# 0 days 00:00:00.057500             NaN                           NaN
# 0 days 00:00:00.060000             NaN                           NaN
# 0 days 00:00:00.062500             NaN                           NaN
# 0 days 00:00:00.065000             NaN                           NaN
# 0 days 00:00:00.067500        35.21875                           1.0
# 0 days 00:00:00.070000             NaN                           NaN
# 0 days 00:00:00.072500             NaN                           NaN
# 0 days 00:00:00.075000             NaN                           NaN
# 0 days 00:00:00.077500             NaN                           NaN
# 0 days 00:00:00.080000             NaN                           NaN
# 0 days 00:00:00.082500             NaN                           NaN
# 0 days 00:00:00.085000             NaN                           NaN
# 0 days 00:00:00.087500        35.15625                           1.0
# 0 days 00:00:00.090000             NaN                           NaN
# 0 days 00:00:00.092500             NaN                           NaN
# 0 days 00:00:00.095000             NaN                           NaN
# 0 days 00:00:00.097500             NaN                           NaN
# 0 days 00:00:00.100000             NaN                           NaN
#
#                         386_WHL_SPD_RL  386_WHL_SPD_Checksum_LSB  \
# 0 days 00:00:00.027500        35.40625                       3.0
# 0 days 00:00:00.030000             NaN                       NaN
# 0 days 00:00:00.032500             NaN                       NaN
# 0 days 00:00:00.035000             NaN                       NaN
# 0 days 00:00:00.037500             NaN                       NaN
# 0 days 00:00:00.040000             NaN                       NaN
# 0 days 00:00:00.042500             NaN                       NaN
# 0 days 00:00:00.045000             NaN                       NaN
# 0 days 00:00:00.047500        35.25000                       1.0
# 0 days 00:00:00.050000             NaN                       NaN
# 0 days 00:00:00.052500             NaN                       NaN
# 0 days 00:00:00.055000             NaN                       NaN
# 0 days 00:00:00.057500             NaN                       NaN
# 0 days 00:00:00.060000             NaN                       NaN
# 0 days 00:00:00.062500             NaN                       NaN
# 0 days 00:00:00.065000             NaN                       NaN
# 0 days 00:00:00.067500        35.28125                       3.0
# 0 days 00:00:00.070000             NaN                       NaN
# 0 days 00:00:00.072500             NaN                       NaN
# 0 days 00:00:00.075000             NaN                       NaN
# 0 days 00:00:00.077500             NaN                       NaN
# 0 days 00:00:00.080000             NaN                       NaN
# 0 days 00:00:00.082500             NaN                       NaN
# 0 days 00:00:00.085000             NaN                       NaN
# 0 days 00:00:00.087500        35.31250                       3.0
# 0 days 00:00:00.090000             NaN                       NaN
# 0 days 00:00:00.092500             NaN                       NaN
# 0 days 00:00:00.095000             NaN                       NaN
# 0 days 00:00:00.097500             NaN                       NaN
# 0 days 00:00:00.100000             NaN                       NaN
#
#                         386_WHL_SPD_RR  386_WHL_SPD_Checksum_MSB  \
# 0 days 00:00:00.027500        35.09375                       3.0
# 0 days 00:00:00.030000             NaN                       NaN
# 0 days 00:00:00.032500             NaN                       NaN
# 0 days 00:00:00.035000             NaN                       NaN
# 0 days 00:00:00.037500             NaN                       NaN
# 0 days 00:00:00.040000             NaN                       NaN
# 0 days 00:00:00.042500             NaN                       NaN
# 0 days 00:00:00.045000             NaN                       NaN
# 0 days 00:00:00.047500        35.09375                       3.0
# 0 days 00:00:00.050000             NaN                       NaN
# 0 days 00:00:00.052500             NaN                       NaN
# 0 days 00:00:00.055000             NaN                       NaN
# 0 days 00:00:00.057500             NaN                       NaN
# 0 days 00:00:00.060000             NaN                       NaN
# 0 days 00:00:00.062500             NaN                       NaN
# 0 days 00:00:00.065000             NaN                       NaN
# 0 days 00:00:00.067500        35.03125                       3.0
# 0 days 00:00:00.070000             NaN                       NaN
# 0 days 00:00:00.072500             NaN                       NaN
# 0 days 00:00:00.075000             NaN                       NaN
# 0 days 00:00:00.077500             NaN                       NaN
# 0 days 00:00:00.080000             NaN                       NaN
# 0 days 00:00:00.082500             NaN                       NaN
# 0 days 00:00:00.085000             NaN                       NaN
# 0 days 00:00:00.087500        34.90625                       3.0
# 0 days 00:00:00.090000             NaN                       NaN
# 0 days 00:00:00.092500             NaN                       NaN
# 0 days 00:00:00.095000             NaN                       NaN
# 0 days 00:00:00.097500             NaN                       NaN
# 0 days 00:00:00.100000             NaN                       NaN
#
#                         164_CR_Esc_StrTqReq  164_CF_Esc_Act  ...  \
# 0 days 00:00:00.027500                  0.0             0.0  ...
# 0 days 00:00:00.030000                  NaN             NaN  ...
# 0 days 00:00:00.032500                  NaN             NaN  ...
# 0 days 00:00:00.035000                  NaN             NaN  ...
# 0 days 00:00:00.037500                  0.0             0.0  ...
# 0 days 00:00:00.040000                  NaN             NaN  ...
# 0 days 00:00:00.042500                  NaN             NaN  ...
# 0 days 00:00:00.045000                  NaN             NaN  ...
# 0 days 00:00:00.047500                  0.0             0.0  ...
# 0 days 00:00:00.050000                  NaN             NaN  ...
# 0 days 00:00:00.052500                  NaN             NaN  ...
# 0 days 00:00:00.055000                  NaN             NaN  ...
# 0 days 00:00:00.057500                  0.0             0.0  ...
# 0 days 00:00:00.060000                  NaN             NaN  ...
# 0 days 00:00:00.062500                  NaN             NaN  ...
# 0 days 00:00:00.065000                  NaN             NaN  ...
# 0 days 00:00:00.067500                  0.0             0.0  ...
# 0 days 00:00:00.070000                  NaN             NaN  ...
# 0 days 00:00:00.072500                  NaN             NaN  ...
# 0 days 00:00:00.075000                  NaN             NaN  ...
# 0 days 00:00:00.077500                  0.0             0.0  ...
# 0 days 00:00:00.080000                  NaN             NaN  ...
# 0 days 00:00:00.082500                  NaN             NaN  ...
# 0 days 00:00:00.085000                  NaN             NaN  ...
# 0 days 00:00:00.087500                  0.0             0.0  ...
# 0 days 00:00:00.090000                  NaN             NaN  ...
# 0 days 00:00:00.092500                  NaN             NaN  ...
# 0 days 00:00:00.095000                  NaN             NaN  ...
# 0 days 00:00:00.097500                  0.0             0.0  ...
# 0 days 00:00:00.100000                  NaN             NaN  ...
#
#                         5a0_CF_PasBkl_FltStat  5a0_CF_DriBkl_FltStat  \
# 0 days 00:00:00.027500                    NaN                    NaN
# 0 days 00:00:00.030000                    NaN                    NaN
# 0 days 00:00:00.032500                    NaN                    NaN
# 0 days 00:00:00.035000                    NaN                    NaN
# 0 days 00:00:00.037500                    NaN                    NaN
# 0 days 00:00:00.040000                    NaN                    NaN
# 0 days 00:00:00.042500                    NaN                    NaN
# 0 days 00:00:00.045000                    NaN                    NaN
# 0 days 00:00:00.047500                    NaN                    NaN
# 0 days 00:00:00.050000                    NaN                    NaN
# 0 days 00:00:00.052500                    NaN                    NaN
# 0 days 00:00:00.055000                    NaN                    NaN
# 0 days 00:00:00.057500                    NaN                    NaN
# 0 days 00:00:00.060000                    NaN                    NaN
# 0 days 00:00:00.062500                    NaN                    NaN
# 0 days 00:00:00.065000                    NaN                    NaN
# 0 days 00:00:00.067500                    NaN                    NaN
# 0 days 00:00:00.070000                    NaN                    NaN
# 0 days 00:00:00.072500                    NaN                    NaN
# 0 days 00:00:00.075000                    NaN                    NaN
# 0 days 00:00:00.077500                    NaN                    NaN
# 0 days 00:00:00.080000                    NaN                    NaN
# 0 days 00:00:00.082500                    NaN                    NaN
# 0 days 00:00:00.085000                    NaN                    NaN
# 0 days 00:00:00.087500                    NaN                    NaN
# 0 days 00:00:00.090000                    NaN                    NaN
# 0 days 00:00:00.092500                    NaN                    NaN
# 0 days 00:00:00.095000                    NaN                    NaN
# 0 days 00:00:00.097500                    NaN                    NaN
# 0 days 00:00:00.100000                    NaN                    NaN
#
#                         5a0_CF_PasBkl_Stat  5a0_CF_DriBkl_Stat  \
# 0 days 00:00:00.027500                 NaN                 NaN
# 0 days 00:00:00.030000                 NaN                 NaN
# 0 days 00:00:00.032500                 NaN                 NaN
# 0 days 00:00:00.035000                 NaN                 NaN
# 0 days 00:00:00.037500                 NaN                 NaN
# 0 days 00:00:00.040000                 NaN                 NaN
# 0 days 00:00:00.042500                 NaN                 NaN
# 0 days 00:00:00.045000                 NaN                 NaN
# 0 days 00:00:00.047500                 NaN                 NaN
# 0 days 00:00:00.050000                 NaN                 NaN
# 0 days 00:00:00.052500                 NaN                 NaN
# 0 days 00:00:00.055000                 NaN                 NaN
# 0 days 00:00:00.057500                 NaN                 NaN
# 0 days 00:00:00.060000                 NaN                 NaN
# 0 days 00:00:00.062500                 NaN                 NaN
# 0 days 00:00:00.065000                 NaN                 NaN
# 0 days 00:00:00.067500                 NaN                 NaN
# 0 days 00:00:00.070000                 NaN                 NaN
# 0 days 00:00:00.072500                 NaN                 NaN
# 0 days 00:00:00.075000                 NaN                 NaN
# 0 days 00:00:00.077500                 NaN                 NaN
# 0 days 00:00:00.080000                 NaN                 NaN
# 0 days 00:00:00.082500                 NaN                 NaN
# 0 days 00:00:00.085000                 NaN                 NaN
# 0 days 00:00:00.087500                 NaN                 NaN
# 0 days 00:00:00.090000                 NaN                 NaN
# 0 days 00:00:00.092500                 NaN                 NaN
# 0 days 00:00:00.095000                 NaN                 NaN
# 0 days 00:00:00.097500                 NaN                 NaN
# 0 days 00:00:00.100000                 NaN                 NaN
#
#                         5a0_CF_SWL_Ind  5a0_CF_Acu_FltStat  \
# 0 days 00:00:00.027500             NaN                 NaN
# 0 days 00:00:00.030000             NaN                 NaN
# 0 days 00:00:00.032500             NaN                 NaN
# 0 days 00:00:00.035000             NaN                 NaN
# 0 days 00:00:00.037500             NaN                 NaN
# 0 days 00:00:00.040000             NaN                 NaN
# 0 days 00:00:00.042500             NaN                 NaN
# 0 days 00:00:00.045000             NaN                 NaN
# 0 days 00:00:00.047500             NaN                 NaN
# 0 days 00:00:00.050000             NaN                 NaN
# 0 days 00:00:00.052500             NaN                 NaN
# 0 days 00:00:00.055000             NaN                 NaN
# 0 days 00:00:00.057500             NaN                 NaN
# 0 days 00:00:00.060000             NaN                 NaN
# 0 days 00:00:00.062500             NaN                 NaN
# 0 days 00:00:00.065000             NaN                 NaN
# 0 days 00:00:00.067500             NaN                 NaN
# 0 days 00:00:00.070000             NaN                 NaN
# 0 days 00:00:00.072500             NaN                 NaN
# 0 days 00:00:00.075000             NaN                 NaN
# 0 days 00:00:00.077500             NaN                 NaN
# 0 days 00:00:00.080000             NaN                 NaN
# 0 days 00:00:00.082500             NaN                 NaN
# 0 days 00:00:00.085000             NaN                 NaN
# 0 days 00:00:00.087500             NaN                 NaN
# 0 days 00:00:00.090000             NaN                 NaN
# 0 days 00:00:00.092500             NaN                 NaN
# 0 days 00:00:00.095000             NaN                 NaN
# 0 days 00:00:00.097500             NaN                 NaN
# 0 days 00:00:00.100000             NaN                 NaN
#
#                         5a0_CF_Acu_ExtOfSab  5a0_CF_Acu_Dtc  \
# 0 days 00:00:00.027500                  NaN             NaN
# 0 days 00:00:00.030000                  NaN             NaN
# 0 days 00:00:00.032500                  NaN             NaN
# 0 days 00:00:00.035000                  NaN             NaN
# 0 days 00:00:00.037500                  NaN             NaN
# 0 days 00:00:00.040000                  NaN             NaN
# 0 days 00:00:00.042500                  NaN             NaN
# 0 days 00:00:00.045000                  NaN             NaN
# 0 days 00:00:00.047500                  NaN             NaN
# 0 days 00:00:00.050000                  NaN             NaN
# 0 days 00:00:00.052500                  NaN             NaN
# 0 days 00:00:00.055000                  NaN             NaN
# 0 days 00:00:00.057500                  NaN             NaN
# 0 days 00:00:00.060000                  NaN             NaN
# 0 days 00:00:00.062500                  NaN             NaN
# 0 days 00:00:00.065000                  NaN             NaN
# 0 days 00:00:00.067500                  NaN             NaN
# 0 days 00:00:00.070000                  NaN             NaN
# 0 days 00:00:00.072500                  NaN             NaN
# 0 days 00:00:00.075000                  NaN             NaN
# 0 days 00:00:00.077500                  NaN             NaN
# 0 days 00:00:00.080000                  NaN             NaN
# 0 days 00:00:00.082500                  NaN             NaN
# 0 days 00:00:00.085000                  NaN             NaN
# 0 days 00:00:00.087500                  NaN             NaN
# 0 days 00:00:00.090000                  NaN             NaN
# 0 days 00:00:00.092500                  NaN             NaN
# 0 days 00:00:00.095000                  NaN             NaN
# 0 days 00:00:00.097500                  NaN             NaN
# 0 days 00:00:00.100000                  NaN             NaN
#
#                         5a0_CF_Acu_NumOfFlt  57f_HU_Type
# 0 days 00:00:00.027500                  NaN          NaN
# 0 days 00:00:00.030000                  NaN          NaN
# 0 days 00:00:00.032500                  NaN          NaN
# 0 days 00:00:00.035000                  NaN          NaN
# 0 days 00:00:00.037500                  NaN          NaN
# 0 days 00:00:00.040000                  NaN          NaN
# 0 days 00:00:00.042500                  NaN          NaN
# 0 days 00:00:00.045000                  NaN          NaN
# 0 days 00:00:00.047500                  NaN          NaN
# 0 days 00:00:00.050000                  NaN          NaN
# 0 days 00:00:00.052500                  NaN          NaN
# 0 days 00:00:00.055000                  NaN          NaN
# 0 days 00:00:00.057500                  NaN          NaN
# 0 days 00:00:00.060000                  NaN          NaN
# 0 days 00:00:00.062500                  NaN          NaN
# 0 days 00:00:00.065000                  NaN          NaN
# 0 days 00:00:00.067500                  NaN          NaN
# 0 days 00:00:00.070000                  NaN          NaN
# 0 days 00:00:00.072500                  NaN          NaN
# 0 days 00:00:00.075000                  NaN          NaN
# 0 days 00:00:00.077500                  NaN          NaN
# 0 days 00:00:00.080000                  NaN          NaN
# 0 days 00:00:00.082500                  NaN          NaN
# 0 days 00:00:00.085000                  NaN          NaN
# 0 days 00:00:00.087500                  NaN          NaN
# 0 days 00:00:00.090000                  NaN          NaN
# 0 days 00:00:00.092500                  NaN          NaN
# 0 days 00:00:00.095000                  NaN          NaN
# 0 days 00:00:00.097500                  NaN          NaN
# 0 days 00:00:00.100000                  NaN          NaN
#
# [30 rows x 688 columns]

# %%
df_merged = df_merged.ffill()
df_merged
# Out:
#                         386_WHL_SPD_FL  386_WHL_SPD_AliveCounter_LSB  \
# 0 days 00:00:00.027500        35.43750                           2.0
# 0 days 00:00:00.030000        35.43750                           2.0
# 0 days 00:00:00.032500        35.43750                           2.0
# 0 days 00:00:00.035000        35.43750                           2.0
# 0 days 00:00:00.037500        35.43750                           2.0
# ...                                ...                           ...
# 0 days 00:23:51.480000         0.03125                           0.0
# 0 days 00:23:51.482500         0.03125                           0.0
# 0 days 00:23:51.485000         0.03125                           0.0
# 0 days 00:23:51.487500         0.00000                           1.0
# 0 days 00:23:51.490000         0.00000                           1.0
#
#                         386_WHL_SPD_FR  386_WHL_SPD_AliveCounter_MSB  \
# 0 days 00:00:00.027500        35.15625                           0.0
# 0 days 00:00:00.030000        35.15625                           0.0
# 0 days 00:00:00.032500        35.15625                           0.0
# 0 days 00:00:00.035000        35.15625                           0.0
# 0 days 00:00:00.037500        35.15625                           0.0
# ...                                ...                           ...
# 0 days 00:23:51.480000         0.03125                           3.0
# 0 days 00:23:51.482500         0.03125                           3.0
# 0 days 00:23:51.485000         0.03125                           3.0
# 0 days 00:23:51.487500         0.03125                           3.0
# 0 days 00:23:51.490000         0.03125                           3.0
#
#                         386_WHL_SPD_RL  386_WHL_SPD_Checksum_LSB  \
# 0 days 00:00:00.027500        35.40625                       3.0
# 0 days 00:00:00.030000        35.40625                       3.0
# 0 days 00:00:00.032500        35.40625                       3.0
# 0 days 00:00:00.035000        35.40625                       3.0
# 0 days 00:00:00.037500        35.40625                       3.0
# ...                                ...                       ...
# 0 days 00:23:51.480000         0.03125                       1.0
# 0 days 00:23:51.482500         0.03125                       1.0
# 0 days 00:23:51.485000         0.03125                       1.0
# 0 days 00:23:51.487500         0.03125                       2.0
# 0 days 00:23:51.490000         0.03125                       2.0
#
#                         386_WHL_SPD_RR  386_WHL_SPD_Checksum_MSB  \
# 0 days 00:00:00.027500        35.09375                       3.0
# 0 days 00:00:00.030000        35.09375                       3.0
# 0 days 00:00:00.032500        35.09375                       3.0
# 0 days 00:00:00.035000        35.09375                       3.0
# 0 days 00:00:00.037500        35.09375                       3.0
# ...                                ...                       ...
# 0 days 00:23:51.480000         0.03125                       3.0
# 0 days 00:23:51.482500         0.03125                       3.0
# 0 days 00:23:51.485000         0.03125                       3.0
# 0 days 00:23:51.487500         0.03125                       2.0
# 0 days 00:23:51.490000         0.03125                       2.0
#
#                         164_CR_Esc_StrTqReq  164_CF_Esc_Act  ...  \
# 0 days 00:00:00.027500                  0.0             0.0  ...
# 0 days 00:00:00.030000                  0.0             0.0  ...
# 0 days 00:00:00.032500                  0.0             0.0  ...
# 0 days 00:00:00.035000                  0.0             0.0  ...
# 0 days 00:00:00.037500                  0.0             0.0  ...
# ...                                     ...             ...  ...
# 0 days 00:23:51.480000                  0.0             0.0  ...
# 0 days 00:23:51.482500                  0.0             0.0  ...
# 0 days 00:23:51.485000                  0.0             0.0  ...
# 0 days 00:23:51.487500                  0.0             0.0  ...
# 0 days 00:23:51.490000                  0.0             0.0  ...
#
#                         5a0_CF_PasBkl_FltStat  5a0_CF_DriBkl_FltStat  \
# 0 days 00:00:00.027500                    NaN                    NaN
# 0 days 00:00:00.030000                    NaN                    NaN
# 0 days 00:00:00.032500                    NaN                    NaN
# 0 days 00:00:00.035000                    NaN                    NaN
# 0 days 00:00:00.037500                    NaN                    NaN
# ...                                       ...                    ...
# 0 days 00:23:51.480000                    0.0                    0.0
# 0 days 00:23:51.482500                    0.0                    0.0
# 0 days 00:23:51.485000                    0.0                    0.0
# 0 days 00:23:51.487500                    0.0                    0.0
# 0 days 00:23:51.490000                    0.0                    0.0
#
#                         5a0_CF_PasBkl_Stat  5a0_CF_DriBkl_Stat  \
# 0 days 00:00:00.027500                 NaN                 NaN
# 0 days 00:00:00.030000                 NaN                 NaN
# 0 days 00:00:00.032500                 NaN                 NaN
# 0 days 00:00:00.035000                 NaN                 NaN
# 0 days 00:00:00.037500                 NaN                 NaN
# ...                                    ...                 ...
# 0 days 00:23:51.480000                 0.0                 1.0
# 0 days 00:23:51.482500                 0.0                 1.0
# 0 days 00:23:51.485000                 0.0                 1.0
# 0 days 00:23:51.487500                 0.0                 1.0
# 0 days 00:23:51.490000                 0.0                 1.0
#
#                         5a0_CF_SWL_Ind  5a0_CF_Acu_FltStat  \
# 0 days 00:00:00.027500             NaN                 NaN
# 0 days 00:00:00.030000             NaN                 NaN
# 0 days 00:00:00.032500             NaN                 NaN
# 0 days 00:00:00.035000             NaN                 NaN
# 0 days 00:00:00.037500             NaN                 NaN
# ...                                ...                 ...
# 0 days 00:23:51.480000             1.0                 1.0
# 0 days 00:23:51.482500             1.0                 1.0
# 0 days 00:23:51.485000             1.0                 1.0
# 0 days 00:23:51.487500             1.0                 1.0
# 0 days 00:23:51.490000             1.0                 1.0
#
#                         5a0_CF_Acu_ExtOfSab  5a0_CF_Acu_Dtc  \
# 0 days 00:00:00.027500                  NaN             NaN
# 0 days 00:00:00.030000                  NaN             NaN
# 0 days 00:00:00.032500                  NaN             NaN
# 0 days 00:00:00.035000                  NaN             NaN
# 0 days 00:00:00.037500                  NaN             NaN
# ...                                     ...             ...
# 0 days 00:23:51.480000                  2.0         38035.0
# 0 days 00:23:51.482500                  2.0         38035.0
# 0 days 00:23:51.485000                  2.0         38035.0
# 0 days 00:23:51.487500                  2.0         38035.0
# 0 days 00:23:51.490000                  2.0         38035.0
#
#                         5a0_CF_Acu_NumOfFlt  57f_HU_Type
# 0 days 00:00:00.027500                  NaN          NaN
# 0 days 00:00:00.030000                  NaN          NaN
# 0 days 00:00:00.032500                  NaN          NaN
# 0 days 00:00:00.035000                  NaN          NaN
# 0 days 00:00:00.037500                  NaN          NaN
# ...                                     ...          ...
# 0 days 00:23:51.480000                  2.0         96.0
# 0 days 00:23:51.482500                  2.0         96.0
# 0 days 00:23:51.485000                  2.0         96.0
# 0 days 00:23:51.487500                  2.0         96.0
# 0 days 00:23:51.490000                  2.0         96.0
#
# [572586 rows x 688 columns]
